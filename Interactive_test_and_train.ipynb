# %% [markdown]
# # Interactive train and test with WER in sentence length order

# %% [markdown]
# ## Setup

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import sys
sys.path.append('/home/catskills/Desktop/openasr20/end2end_asr_pytorch')

# %%
import os
os.environ['IN_JUPYTER']='True'

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
# !rm -rf runs

# %%
from chunk_size import chunk_size
from glob import glob
from models.asr.transformer import Transformer, Encoder, Decoder
from torch.autograd import Variable
from torch.cuda.amp import GradScaler, autocast
from utils import constant
from utils.data_loader import SpectrogramDataset, AudioDataLoader, BucketingSampler
from utils.functions import save_model, load_model, init_transformer_model, init_optimizer
from utils.lstm_utils import LM
from utils.metrics import calculate_metrics, calculate_cer, calculate_wer, calculate_cer_en_zh
from utils.optimizer import NoamOpt
import json, logging, math, os, random, time, torch, sys, random
import numpy as np
import torch.nn as nn
from Trainer import Trainer

# %%
language='amharic'
stage='NIST'
chunks = list(sorted(glob(f'{stage}/openasr20_{language}/build/transcription_split/*.txt')))
print(len(chunks), 'chunks')
size_chunks=list(sorted([chunk_size(fn) for fn in chunks]))
size_chunk_files={x:[] for x,y in size_chunks}
for x,y in size_chunks:
    size_chunk_files[x].append(y)
size_chunk_distribution={x:0 for x,y in size_chunks}
for x,y in size_chunks:
    size_chunk_distribution[x] += 1
plt.figure(figsize=(10,4))
plt.hist([np.log2(x) for x,y in size_chunks], bins=max(size_chunk_distribution))
plt.title("Zipf's Law for sentences")
plt.xlabel("$\log_2(|S|)$");
# Out:
# 9842 chunks

# %%
sizes=[x for x in size_chunk_files]

# %%
chunks[0:2]
# Out:
# ['NIST/openasr20_amharic/build/transcription_split/BABEL_OP3_307_14229_20140503_233516_inLine_000_2.715_3.225.txt',
#  'NIST/openasr20_amharic/build/transcription_split/BABEL_OP3_307_14229_20140503_233516_inLine_001_5.215_8.035.txt']

# %%
size_chunk_files[sizes[-1]]
# Out:
# ['NIST/openasr20_amharic/build/transcription_split/BABEL_OP3_307_61971_20140811_182130_outLine_025_155.085_178.495.txt']

# %%
L=[]
for text in size_chunk_files[1]+size_chunk_files[2]+size_chunk_files[3]+size_chunk_files[4]:
    audio=text.replace('transcription','audio').replace('txt', 'wav')
    L.append(f'{audio},{text}')
random.shuffle(L)

# %%
print(f'{len(L)} samples in training set of length 1 to 4 covers {100*len(L)/len(chunks):.2f}%')
# Out:
# 4706 samples in training set of length 1 to 4 covers 47.82%

# %%
manifest_file_path=f'analysis/{language}/size_1.csv'
with open(manifest_file_path,'w') as f:
    f.write('\n'.join(L))

model_dir=f'save/{language}_end2end_asr_pytorch_drop0.1_cnn_batch12_4_vgg_layer4'

args=constant.args
args.continue_from=None
args.cuda = True
args.labels_path = f'analysis/{language}/{language}_characters.json'
args.lr = 1e-4
args.name = f'{language}_end2end_asr_pytorch_drop0.1_cnn_batch12_4_vgg_layer4'
args.save_folder = f'save'
args.epochs = 5
args.save_every = 1
args.feat_extractor = f'vgg_cnn'
args.dropout = 0.1
args.num_layers = 4
args.num_heads = 8
args.dim_model = 512
args.dim_key = 64
args.dim_value = 64
args.dim_input = 161
args.dim_inner = 2048
args.dim_emb = 512
args.shuffle=True
args.min_lr = 1e-6
args.k_lr = 1
args.sample_rate=8000
args.train_manifest_list = [manifest_file_path]
args.continue_from=f'{model_dir}/best_model.th'

args.augment=True

audio_conf = dict(sample_rate=args.sample_rate,
                  window_size=args.window_size,
                  window_stride=args.window_stride,
                  window=args.window,
                  noise_dir=args.noise_dir,
                  noise_prob=args.noise_prob,
                  noise_levels=(args.noise_min, args.noise_max))

with open(args.labels_path, 'r') as label_file:
    labels = str(''.join(json.load(label_file)))

# add PAD_CHAR, SOS_CHAR, EOS_CHAR
labels = constant.PAD_CHAR + constant.SOS_CHAR + constant.EOS_CHAR + labels
label2id, id2label = {}, {}
count = 0
for i in range(len(labels)):
    if labels[i] not in label2id:
        label2id[labels[i]] = count
        id2label[count] = labels[i]
        count += 1
    else:
        print("multiple label: ", labels[i])

if constant.args.continue_from:
        model, opt, epoch, metrics, loaded_args, label2id, id2label = load_model(
            constant.args.continue_from)
        start_epoch = epoch  # index starts from zero
        verbose = constant.args.verbose
else:
    model = init_transformer_model(constant.args, label2id, id2label)
    opt = init_optimizer(constant.args, model, "noam")

start_epoch = epoch
metrics = None
loaded_args = None
verbose = True

constant.USE_CUDA=True

# %%
train_data = SpectrogramDataset(audio_conf, manifest_filepath_list=args.train_manifest_list, 
                                label2id=label2id, normalize=True, augment=args.augment)

# %%
loss_type = args.loss
model = model.cuda(0)
num_epochs = start_epoch + 1000

# %% [markdown]
# ## Training

# %%
args.batch_size = 9
train_sampler = BucketingSampler(train_data, batch_size=args.batch_size)
train_loader = AudioDataLoader(train_data, num_workers=args.num_workers, batch_sampler=train_sampler)

# %%
trainer = Trainer()

# %%
start_epoch, num_epochs

# %%
trainer.train(model, train_loader, train_sampler, opt, loss_type, start_epoch, num_epochs, label2id, id2label, metrics)

# %% [markdown]
# ## Eval

# %%
args.batch_size = 8
train_sampler = BucketingSampler(train_data, batch_size=args.batch_size)
train_loader = AudioDataLoader(train_data, num_workers=args.num_workers, batch_sampler=train_sampler)

# %%
args.verbose = True

# %%
smoothing = constant.args.label_smoothing

# %%
model.eval();

# %%
R = []

valid_loader = train_loader
total_valid_loss, total_valid_cer, total_valid_wer, total_valid_char, total_valid_word = 0, 0, 0, 0, 0
for i, (data) in enumerate(valid_loader):
    src, tgt, src_percentages, src_lengths, tgt_lengths = data
    src = src.cuda()
    tgt = tgt.cuda()
    with autocast():
        pred, gold, hyp_seq, gold_seq = model(src, src_lengths, tgt, verbose=False)

    seq_length = pred.size(1)
    sizes = Variable(src_percentages.mul_(int(seq_length)).int(), requires_grad=False)

    loss, num_correct = calculate_metrics(
        pred, gold, input_lengths=sizes, target_lengths=tgt_lengths, smoothing=smoothing, loss_type=loss_type)

    if loss.item() == float('Inf'):
        logging.info("Found infinity loss, masking")
        loss = torch.where(loss != loss, torch.zeros_like(loss), loss) # NaN masking
        continue

    try: # handle case for CTC
        strs_gold, strs_hyps = [], []
        for ut_gold in gold_seq:
            str_gold = ""
            for x in ut_gold:
                if int(x) == constant.PAD_TOKEN:
                    break
                str_gold = str_gold + id2label[int(x)]
            strs_gold.append(str_gold)
        for ut_hyp in hyp_seq:
            str_hyp = ""
            for x in ut_hyp:
                if int(x) == constant.PAD_TOKEN:
                    break
                str_hyp = str_hyp + id2label[int(x)]
            strs_hyps.append(str_hyp)
    except Exception as e:
        print(e)
        logging.info("NaN predictions")
        continue

    for j in range(len(strs_hyps)):
        strs_hyps[j] = strs_hyps[j].replace(constant.SOS_CHAR, '').replace(constant.EOS_CHAR, '')
        strs_gold[j] = strs_gold[j].replace(constant.SOS_CHAR, '').replace(constant.EOS_CHAR, '')
        cer = calculate_cer(strs_hyps[j].replace(' ', ''), strs_gold[j].replace(' ', ''))
        wer = calculate_wer(strs_hyps[j], strs_gold[j])
        success = 'SUCCESS' if strs_gold[j] == strs_hyps[j] else ''
        print(f'[{j}] cer {cer} wer {wer} gold {strs_gold[j]}:{len(strs_gold[j])} hyp {strs_hyps[j]}:{len(strs_hyps[j])} {success}')
        R.append((cer, wer, strs_gold[j], strs_hyps[j], success))
        total_valid_cer += cer
        total_valid_wer += wer
        total_valid_char += len(strs_gold[j].replace(' ', ''))
        total_valid_word += len(strs_gold[j].split(" "))

    total_valid_loss += loss.item()
# Out:
# [0] cer 3 wer 2 gold ዛሬ እንመለሳለን እንመለሳለን:18 hyp ዛሬ ታንመለለለን እንመለንለን:18
# [1] cer 2 wer 2 gold የለም ብቻዬን ነኝ ቢሮ:14 hyp የለም ብቻዬም የኝ ቢሮ:14
# [2] cer 2 wer 2 gold እሱ አባይነው ያለው እንደ:16 hyp እሱ አባርነው ያለው አንደ:16
# [3] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [4] cer 0 wer 0 gold ልጇ ደህና ነው:9 hyp ልጇ ደህና ነው:9 SUCCESS
# [5] cer 0 wer 0 gold ትለያለሽ:5 hyp ትለያለሽ:5 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [0] cer 0 wer 0 gold የእዛኔ ታዲያ:8 hyp የእዛኔ ታዲያ:8 SUCCESS
# [1] cer 3 wer 3 gold ለመደ ገበያው ምናምን:13 hyp የመደ ገበያው ምና ና:13
# [2] cer 0 wer 0 gold ምን ሥራ ጀመርክ እንደ:14 hyp ምን ሥራ ጀመርክ እንደ:14 SUCCESS
# [3] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [4] cer 0 wer 0 gold እንግዲህ ቆይ:8 hyp እንግዲህ ቆይ:8 SUCCESS
# [5] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ማን:2 hyp ማን:2 SUCCESS
# [0] cer 3 wer 3 gold ደሞም አያስቡልሽም አዎ ስለዚህ:19 hyp ደሞም አያስቡልሽምምአዎ አለህህ :20
# [1] cer 1 wer 1 gold እ ሁሉም ሰላም ነው:12 hyp እ ሁሉ  ሰላም ነው:12
# [2] cer 0 wer 0 gold ሄሎ ሀኒ ይሰማል:10 hyp ሄሎ ሀኒ ይሰማል:10 SUCCESS
# [3] cer 0 wer 0 gold ኦኬ ሁለታችሁ ናችሁ:12 hyp ኦኬ ሁለታችሁ ናችሁ:12 SUCCESS
# [4] cer 0 wer 0 gold ያው:2 hyp ያው:2 SUCCESS
# [5] cer 0 wer 0 gold ሄድፎን ነው:7 hyp ሄድፎን ነው:7 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ ጤና ይስጥልኝ:11 hyp ሄሎ ጤና ይስጥልኝ:11 SUCCESS
# [7] cer 0 wer 0 gold ኧረ እባክሽ:7 hyp ኧረ እባክሽ:7 SUCCESS
# [0] cer 5 wer 2 gold እንዳውም ልጃቸውን ዐባይ የበሉትኝ:21 hyp እንዳውም ልጃቸውን የባበበየበሽኝ:20
# [1] cer 1 wer 1 gold ም  እራቅ ብሎብሻል:12 hyp ም   ራቅ ብሎብሻል:12
# [2] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [3] cer 0 wer 0 gold ደህና ነው:6 hyp ደህና ነው:6 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold እንደት:4 hyp እንደት:4 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold አዎ ሁሉም ደህና ናቸው:14 hyp አዎ ሁሉም ደህና ናቸው:14 SUCCESS
# [1] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [2] cer 0 wer 0 gold እየተቆራረጠ:7 hyp እየተቆራረጠ:7 SUCCESS
# [3] cer 4 wer 2 gold አዎ ፈተና ምናምን:11 hyp አዎ ትተ ችምንም  :12
# [4] cer 1 wer 1 gold የ  ምን ልጠይቅልሽ:12 hyp የ  ምን ልጠይቅሽ:11
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 2 gold አቤት አቤት አቤት አቤት:15 hyp አቤት አቤት አቤትምአቤት:15
# [1] cer 1 wer 1 gold ኦኬ አንተ ደህና ነህ:13 hyp ኦኬ አንተ ደህና አህ:13
# [2] cer 2 wer 3 gold  ቃ ልትዘጋው ነው:11 hyp  ያ ልት ጋው ነው:11
# [3] cer 0 wer 0 gold እኔ:2 hyp እኔ:2 SUCCESS
# [4] cer 0 wer 0 gold ዘሩ ሲመጣ:6 hyp ዘሩ ሲመጣ:6 SUCCESS
# [5] cer 0 wer 0 gold ይርጋለም ጋር:8 hyp ይርጋለም ጋር:8 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [0] cer 10 wer 3 gold የቡናውን ከትናንትና እንደውም:18 hyp እጎና   አትናንናና እናና:16
# [1] cer 0 wer 0 gold እሺ ወደ እዛ ና:10 hyp እሺ ወደ እዛ ና:10 SUCCESS
# [2] cer 1 wer 1 gold ሥራ ቆንጆ ነው:9 hyp ሥራ ቆንጆ ሥው:9
# [3] cer 0 wer 0 gold አይ:2 hyp አይ:2 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 2 wer 2 gold እኔ የምልህ:7 hyp ማኔ የምየህ:7
# [6] cer 0 wer 0 gold አቤት አቤት:7 hyp አቤት አቤት:7 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 1 gold እሺ ጂንስ ሱሪስ አትፈልግም:17 hyp እሺ ጂንስ ሱሪስ እትፈልፈም:17
# [1] cer 0 wer 0 gold ፈተናውን ሊሰጠን አዎ:13 hyp ፈተናውን ሊሰጠን አዎ:13 SUCCESS
# [2] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [3] cer 0 wer 0 gold እንገናኛለን ኧረ:10 hyp እንገናኛለን ኧረ :11
# [4] cer 0 wer 0 gold ሚጣ ደህና ናት:9 hyp ሚጣ ደህና ናት:9 SUCCESS
# [5] cer 0 wer 0 gold ዝውውርም:5 hyp ዝውውርም:5 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold በጣም የሚከብድ ነገር ነው:16 hyp በጣም የሚከብድ ነገር ነው:16 SUCCESS
# [1] cer 2 wer 1 gold ያወራል አዎ ያወራል ይሰበስበዋል:20 hyp ያወራል አዎ ያወራል ይሰዋዋበዋል:20
# [2] cer 2 wer 2 gold መሰረት ለየትኛው መሰረት:15 hyp የሰረት ለየትኛው መሰረ:14
# [3] cer 0 wer 0 gold ሄሎ ዴቪድ ሙባረክ ነኝ:14 hyp ሄሎ ዴቪድ ሙባረክ ነኝ:14 SUCCESS
# [4] cer 0 wer 0 gold አሚኑ አቤት:7 hyp አሚኑ አቤት:7 SUCCESS
# [5] cer 1 wer 2 gold አዎ ብለናል እንግዲህ:13 hyp አዎ ብለ ል እንግዲህ:13
# [6] cer 0 wer 0 gold በእውነት:5 hyp በእውነት:5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እ እኮ እንደናፈቀ በጣም:15 hyp እ እኮ እንደናፈቀ በጣም:15 SUCCESS
# [1] cer 3 wer 2 gold ውይ ማምሸትም ጀምረሻል እንደ:18 hyp ውይ ማምሸትም ጀምረሻልረነንዲ:18
# [2] cer 0 wer 0 gold ሄሎ ሥራ ጀምሬያለሁ:12 hyp ሄሎ ሥራ ጀምሬያለሁ:12 SUCCESS
# [3] cer 1 wer 1 gold የምታናግረው ነገር የለህም:16 hyp የምታናግረው ነገር የለህምም:17
# [4] cer 0 wer 0 gold ፈተና ምናምን:8 hyp ፈተና ምናምን:8 SUCCESS
# [5] cer 0 wer 0 gold ማርያምን:5 hyp ማርያምን:5 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [0] cer 0 wer 0 gold የኒዬ ደህና ናት:10 hyp የኒዬ ደህና ናት:10 SUCCESS
# [1] cer 0 wer 0 gold አይ እ:4 hyp አይ እ:4 SUCCESS
# [2] cer 1 wer 1 gold እግዚአብሔር ይመስገን:13 hyp እግዚአብሔር ይመመገን:13
# [3] cer 0 wer 0 gold ውይ በአላህ:7 hyp ውይ በአላህ:7 SUCCESS
# [4] cer 1 wer 1 gold ምንድን ነው የሚልሽ ቆየሽ:16 hyp ምንድን ነው የሚየሽ ቆየሽ:16
# [5] cer 2 wer 2 gold አዎ ሥራ ልገባ:9 hyp አዎ አራ ልገ:8
# [6] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 2 wer 3 gold አዎ በእናትህ ነው ያልከው:16 hyp አዎ በእ ትህ ነው ያከከው:16
# [1] cer 0 wer 0 gold ጠፍተሀል ምነው በሰላም ነው:17 hyp ጠፍተሀል ምነው በሰላም ነው:17 SUCCESS
# [2] cer 4 wer 3 gold እያሰፋችሁት ወይንስ ምን እያረጋ :21 hyp እያሰፋችሁት ወይንስ ምንምምያ ጋ ም:22
# [3] cer 0 wer 2 gold ዝናብ በዝናብ ላግዛት አልኩኝ:18 hyp ዝናብ በዝናብ ላግዛትአልኩኝ:17
# [4] cer 0 wer 0 gold በስመ አብ:6 hyp በስመ አብ:6 SUCCESS
# [5] cer 1 wer 1 gold አዎ ደህና ናት በጣም:13 hyp አዎ ደህና ናት ትጣም:13
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold ቴሌ የሚሰራው ተመለሰ ወይ:16 hyp ቴሌ የሚሰራው ተመለሰ ወይ:16 SUCCESS
# [1] cer 0 wer 0 gold እሺ አለሁ አለሁ:10 hyp እሺ አለሁ አለሁ:10 SUCCESS
# [2] cer 0 wer 0 gold አዎ በጣም ፈጠንሽ:11 hyp አዎ በጣም ፈጠንሽ:11 SUCCESS
# [3] cer 0 wer 0 gold የለም:3 hyp የለም:3 SUCCESS
# [4] cer 0 wer 2 gold የት ነው ያለው እሱ:12 hyp የት ነው ያለውእሱ:11
# [5] cer 0 wer 0 gold እና:2 hyp እና:2 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold አይመ :4 hyp አይመ :4 SUCCESS
# [0] cer 3 wer 2 gold አዎ ቦርኮ መስያለሁ አልኩሽኝ:18 hyp አዎ ቦርኮ አስያለሁ አይኩሽ:17
# [1] cer 0 wer 0 gold እ እ ተመችቶሻል:10 hyp እ እ ተመችቶሻል:10 SUCCESS
# [2] cer 0 wer 0 gold ት  ትከታተያለሽ:10 hyp ት  ትከታተያለሽ:10 SUCCESS
# [3] cer 0 wer 0 gold ታዲያ ከተማ ብቻ:10 hyp ታዲያ ከተማ ብቻ:10 SUCCESS
# [4] cer 1 wer 1 gold ምን አለ አዲስ ነገር:13 hyp ምን አለ ነዲስ ነገር:13
# [5] cer 0 wer 0 gold ሄሎ አቤት:6 hyp ሄሎ አቤት:6 SUCCESS
# [6] cer 0 wer 0 gold ሚጣ ደህና ነች:9 hyp ሚጣ ደህና ነች:9 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 3 wer 2 gold አማኑኤል አቆመ አዎ ምንም:16 hyp አማኑኤል አቆመ አቆ አምም:16
# [1] cer 2 wer 1 gold ሲመችሽ ችግር የለም:12 hyp እመራሽ ችግር የለም:12
# [2] cer 0 wer 0 gold እንደምን አደርክ:10 hyp እንደምን አደርክ:10 SUCCESS
# [3] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [4] cer 0 wer 0 gold በያት:3 hyp በያት:3 SUCCESS
# [5] cer 0 wer 0 gold ወይ ጉድ:5 hyp ወይ ጉድ:5 SUCCESS
# [6] cer 0 wer 0 gold በእውነት:5 hyp በእውነት:5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 2 gold ቃሊቲ ነው እንደ ሰፈሩ:14 hyp ቃሊቲ ነው አንደ አፈሩ:14
# [1] cer 0 wer 0 gold ወይዬ ሰላም ነው:10 hyp ወይዬ ሰላም ነው:10 SUCCESS
# [2] cer 2 wer 1 gold ምንድን ነበር የተፈረደባት ሴትዮዋ:21 hyp ምንድን ነበር የተፈረደባት ሴትዮዮት:22
# [3] cer 1 wer 1 gold እ ትምህርት ቤት:10 hyp እ ትምህርት ቤር:10
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold አ:1 hyp አ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 1 wer 1 gold ሄሎ አይሰማም እን :12 hyp ሄሎ አይሰማም እን እ:13
# [1] cer 4 wer 4 gold ደህና ነሽ ግን በተረፈ:14 hyp የህና ነኝ እን በረረፈ:14
# [2] cer 1 wer 1 gold እ አዎ እሱማ በጣም:12 hyp አ አዎ እሱማ በጣም:12
# [3] cer 1 wer 1 gold አልደወለችም ሰሞኑን:12 hyp አልደወለችም ሰሞኑም:12
# [4] cer 0 wer 0 gold ምን አዲስ ነገር አለ:13 hyp ምን አዲስ ነገር አለ:13 SUCCESS
# [5] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [6] cer 0 wer 0 gold ኧረ እባክሽ:7 hyp ኧረ እባክሽ:7 SUCCESS
# [7] cer 0 wer 0 gold አዎ አይ:5 hyp አዎ አይ:5 SUCCESS
# [0] cer 1 wer 2 gold ምናምን እንደት ናቸው:13 hyp ምናምን እንናትናቸው:12
# [1] cer 0 wer 0 gold እሺ እልልሻለሁ እሺ:12 hyp እሺ እልልሻለሁ እሺ:12 SUCCESS
# [2] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [3] cer 0 wer 0 gold እኔ እንጃ አልመጡም:12 hyp እኔ እንጃ አልመጡም:12 SUCCESS
# [4] cer 0 wer 0 gold ለጊዜው:4 hyp ለጊዜው:4 SUCCESS
# [5] cer 0 wer 0 gold ምን አልከኝ ወንድሜ:12 hyp ምን አልከኝ ወንድሜ:12 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ ሄሎ:5 hyp ሄሎ ሄሎ:5 SUCCESS
# [0] cer 0 wer 0 gold ሄሎ አይሰማም:8 hyp ሄሎ አይሰማም:8 SUCCESS
# [1] cer 0 wer 0 gold ያልተጠበቁ ልጆች:10 hyp ያልተጠበቁ ልጆች:10 SUCCESS
# [2] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [3] cer 0 wer 0 gold ሄሎ እ እ:6 hyp ሄሎ እ እ:6 SUCCESS
# [4] cer 0 wer 0 gold ባልዮው እኮ ጠፋ:10 hyp ባልዮው እኮ ጠፋ:10 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 1 wer 1 gold አይፈቀድላትም:8 hyp አይቀቀድላትም:8
# [7] cer 0 wer 0 gold ለእዛ ነው:6 hyp ለእዛ ነው:6 SUCCESS
# [0] cer 1 wer 1 gold አዎ ችግር የለውም:11 hyp አዎ ችግር የለውምም:12
# [1] cer 2 wer 2 gold እሺ አሁን ተገናኘን:12 hyp እሺ አሁን ምገና ን:12
# [2] cer 0 wer 0 gold ካሊድስ ደህና ነው ተሻለው:16 hyp ካሊድስ ደህና ነው ተሻለው:16 SUCCESS
# [3] cer 0 wer 0 gold አዎ እየጠየኳት ነው:12 hyp አዎ እየጠየኳት ነው:12 SUCCESS
# [4] cer 2 wer 2 gold ኧረ በልቻለሁ:8 hyp አረ በልልለሁ:8
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 3 wer 2 gold አላነበብኩም አላየሁም አልሰማሁም:20 hyp አላነበብኩም አላየሁ  አላሰማሁ:19
# [1] cer 1 wer 1 gold ሥራ አሪፍ ነው አይደል:14 hyp ሥራ አሪፍ ነው ናይደል:14
# [2] cer 0 wer 0 gold የለም ዝናብ የለም:11 hyp የለም ዝናብ የለም:11 SUCCESS
# [3] cer 2 wer 2 gold አንቺ መግባት አችይም:13 hyp አንቺ መግውት አችምም:13
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold ኧረ እየ :6 hyp ኧረ እየ :6 SUCCESS
# [7] cer 0 wer 0 gold ይሰማል:4 hyp ይሰማል:4 SUCCESS
# [0] cer 1 wer 1 gold እየሄደች ነበራ አዲስ አባ:16 hyp እየሄደች ነበራ አዲስ አዲ:16
# [1] cer 2 wer 2 gold እስካሁን አልተስማማችሁም እንደ:19 hyp እስካሁን አልተስማማማሁምምእንደ:19
# [2] cer 0 wer 0 gold ደህና ነች እሷ:9 hyp ደህና ነች እሷ:9 SUCCESS
# [3] cer 2 wer 1 gold ምን አልከኝ አልሰማሁህም:15 hyp ምን አልከኝ ነልሰማሁህምም:16
# [4] cer 0 wer 0 gold መድን ወርደዋል:9 hyp መድን ወርደዋል:9 SUCCESS
# [5] cer 0 wer 0 gold ወይዬ:3 hyp ወይዬ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 1 wer 1 gold የቤት:3 hyp የትት:3
# [0] cer 4 wer 2 gold እሺ ነባ እንነግረዋለን እሺ:17 hyp እሺ ነባ እሺግግረ ንንእሺ:16
# [1] cer 2 wer 2 gold ምን ዐይነት ትያትር:12 hyp ምን ዐይትት ትያትርር:13
# [2] cer 0 wer 0 gold እመጣለሁ:5 hyp እመጣለሁ:5 SUCCESS
# [3] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እጋብዝሀለሁ እሺ:10 hyp እጋብዝሀለሁ እሺ:10 SUCCESS
# [1] cer 0 wer 0 gold አሪፍ ነው:6 hyp አሪፍ ነው:6 SUCCESS
# [2] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 1 wer 1 gold እ አዎ:4 hyp ሄ አዎ:4
# [5] cer 2 wer 1 gold ይደረግልሀል:7 hyp ይቼረግልልል:7
# [6] cer 0 wer 0 gold ሰላም ነሽ:6 hyp ሰላም ነሽ:6 SUCCESS
# [7] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [0] cer 0 wer 0 gold ሠርታችሁ መጣችሁ:10 hyp ሠርታችሁ መጣችሁ:10 SUCCESS
# [1] cer 0 wer 0 gold እሺ እሺ:5 hyp እሺ እሺ:5 SUCCESS
# [2] cer 1 wer 1 gold ወይዬ ማን ልበል:10 hyp ወይዬ ማን ልልል:10
# [3] cer 0 wer 0 gold ደክሞኛል እባክህ:10 hyp ደክሞኛል እባክህ:10 SUCCESS
# [4] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ምን:2 hyp ምን:2 SUCCESS
# [0] cer 0 wer 0 gold ይሰማል ሄሎ ይሰማኛል ይሰማኛል:19 hyp ይሰማል ሄሎ ይሰማኛል ይሰማኛል:19 SUCCESS
# [1] cer 3 wer 2 gold አዎ ከሳምንት በኋላ ነው:15 hyp አዎ ከሳምንት በኋላምምሽ:15
# [2] cer 2 wer 2 gold ትምህርት ጀምሪያለሁ ማታ ማታ:18 hyp ትምህርት ጀምሪያለሁ ማማ:15
# [3] cer 0 wer 0 gold አይደል:4 hyp አይደል:4 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold ማን ይዞ ነበር:9 hyp ማን ይዞ ነበር:9 SUCCESS
# [6] cer 0 wer 0 gold አይሰማም:5 hyp አይሰማም:5 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold በቃ እሺ እሺ በቃ:11 hyp በቃ እሺ እሺ በቃ:11 SUCCESS
# [1] cer 1 wer 1 gold ያው አጋጣሚ እነሱ ከመጡ:15 hyp ያው አጋጣሚ አነሱ ከመጡ:15
# [2] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [3] cer 0 wer 0 gold ተመቻቸው:5 hyp ተመቻቸው:5 SUCCESS
# [4] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [1] cer 0 wer 0 gold እነሱ ናቸው እንደዚህ ያሉት:17 hyp እነሱ ናቸው እንደዚህ ያሉት:17 SUCCESS
# [2] cer 0 wer 0 gold በእውነት:5 hyp በእውነት:5 SUCCESS
# [3] cer 0 wer 0 gold ምንም አይልም:8 hyp ምንም አይልም:8 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold ወይዬ:3 hyp ወይዬ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 1 gold ሄሎ መሲ እንደት ዋልሽ:14 hyp ሄሎ መሲ እንደት ዋ:12
# [1] cer 1 wer 1 gold እቤት አዎ ማንም የለም:14 hyp እቤት አዎ ማን  የለም:14
# [2] cer 0 wer 0 gold እንትኑ ወረቀቱ:9 hyp እንትኑ ወረቀቱ:9 SUCCESS
# [3] cer 0 wer 0 gold ድንገት ደብተር:9 hyp ድንገት ደብተር:9 SUCCESS
# [4] cer 0 wer 0 gold ምን ያኮርፋል:8 hyp ምን ያኮርፋል:8 SUCCESS
# [5] cer 0 wer 0 gold እና:2 hyp እና:2 SUCCESS
# [6] cer 0 wer 0 gold ምን:2 hyp ምን:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 2 gold እና በተረፈ ደህና ነሽ:14 hyp እና በተረፈ ደህናናነሽ:14
# [1] cer 0 wer 0 gold የምልህ እኮ:7 hyp የምልህ እኮ:7 SUCCESS
# [2] cer 0 wer 0 gold ሦስት ዐመት ነው:10 hyp ሦስት ዐመት ነው:10 SUCCESS
# [3] cer 0 wer 0 gold አዎ አይቻልም:8 hyp አዎ አይቻልም:8 SUCCESS
# [4] cer 1 wer 1 gold አዎ አልነበርኩም:10 hyp አዎ አልነበርምም:10
# [5] cer 1 wer 1 gold ኧረ አልደወልኩለትም:12 hyp ኧረ አልደወልኩለት:11
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [0] cer 0 wer 0 gold እሰይ ደግ አደረገ:11 hyp እሰይ ደግ አደረገ:11 SUCCESS
# [1] cer 0 wer 0 gold ኧረ ደስ ይላል:9 hyp ኧረ ደስ ይላል:9 SUCCESS
# [2] cer 0 wer 0 gold ማዘር ደህና ናቸው:11 hyp ማዘር ደህና ናቸው:11 SUCCESS
# [3] cer 0 wer 0 gold አቃቂ ነው እሱ:9 hyp አቃቂ ነው እሱ:9 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold ያው የ :5 hyp ያው የ :5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold የት:2 hyp የት:2 SUCCESS
# [1] cer 5 wer 3 gold አዎ ውጭ ነኝ:8 hyp አይ አየንአኝ:8
# [2] cer 1 wer 1 gold ኢንተርኔት ላይ አገኘኸው:15 hyp ኢንተርኔት ላይ አገኘችው:15
# [3] cer 0 wer 0 gold የቷ ሴትዮ:6 hyp የቷ ሴትዮ:6 SUCCESS
# [4] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ምን አለ አሁን:9 hyp ምን አለ አሁን:9 SUCCESS
# [1] cer 2 wer 2 gold ምሳ መውጣታቸው አይቀር እ:16 hyp በሳልመውጣታቸው አይቀር እ:16
# [2] cer 1 wer 1 gold አስራ ስምንት:8 hyp አስራ ስምንም:8
# [3] cer 0 wer 0 gold የት የት:5 hyp የት የት:5 SUCCESS
# [4] cer 0 wer 2 gold እንደት ነህ ፍቄ:10 hyp እንደት ነህፍቄ:9
# [5] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሰማንያ:4 hyp ሰማንያ:4 SUCCESS
# [0] cer 0 wer 2 gold ልናግዛቸው ነው:9 hyp ልናግዛቸውነው:8
# [1] cer 4 wer 3 gold ጓደኛሽን አየሁልሽ በሱቁ ስታልፍ:20 hyp ጓደኛሽን አየሁሽሽ በሱሽ በታል  :21
# [2] cer 1 wer 1 gold ትችላለህ ትችላለህ እንጂ:15 hyp ትችላለህ ትችላላህ እንጂ:15
# [3] cer 3 wer 2 gold እ ላገኛት አስቤያለሁ:13 hyp እ ላገትት አስያያያሁ:13
# [4] cer 1 wer 2 gold ለማንኛውም በተረፈ ደህና ነህ:18 hyp ለማንኛውም በተረፈ ደህነህ:16
# [5] cer 0 wer 0 gold አይደል:4 hyp አይደል:4 SUCCESS
# [6] cer 0 wer 0 gold አይሆንም:5 hyp አይሆንም:5 SUCCESS
# [7] cer 0 wer 0 gold እየመጣህ ነው:8 hyp እየመጣህ ነው:8 SUCCESS
# [0] cer 0 wer 0 gold እግዚአብሔር ይመስገን ሰላም ነሽ:20 hyp እግዚአብሔር ይመስገን ሰላም ነሽ :21
# [1] cer 3 wer 1 gold እንጂ በቅርበት አልተገናኘንም:18 hyp እንጂ በቅርበት አልተናናኘናምም:19
# [2] cer 1 wer 1 gold ልትል ነው የምትመጣው:13 hyp ልትል ነው የምመመጣው:13
# [3] cer 0 wer 0 gold አዎ አልፏል:7 hyp አዎ አልፏል:7 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ አይሰማም ምን:11 hyp ሄሎ አይሰማም ምን:11 SUCCESS
# [5] cer 0 wer 0 gold ምን አልሽኝ:7 hyp ምን አልሽኝ:7 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold እ መንገድ:6 hyp እ መንገ:5
# [1] cer 0 wer 0 gold እንደ ሥራ በለው:10 hyp እንደ ሥራ በለው:10 SUCCESS
# [2] cer 0 wer 0 gold እግዚአብሔር ይመስገን ሰላም ነው:20 hyp እግዚአብሔር ይመስገን ሰላም ነው :21
# [3] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [4] cer 0 wer 0 gold አሁን ይሰማል አ:10 hyp አሁን ይሰማል አ:10 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [7] cer 0 wer 0 gold ቀጣይ:3 hyp ቀጣይ:3 SUCCESS
# [0] cer 0 wer 2 gold እንደት ነሽ እ:9 hyp እንደት ነሽእ:8
# [1] cer 0 wer 0 gold ከእዛ ያው:6 hyp ከእዛ ያው:6 SUCCESS
# [2] cer 0 wer 0 gold ማንን:3 hyp ማንን:3 SUCCESS
# [3] cer 0 wer 0 gold እሺ በተረ :7 hyp እሺ በተረ :7 SUCCESS
# [4] cer 3 wer 3 gold ኤደን አልደወለችልሽም:13 hyp ኤሊው አልደወለችል ምም:14
# [5] cer 0 wer 0 gold እ ከፍሬ ጋር:8 hyp እ ከፍሬ ጋር:8 SUCCESS
# [6] cer 0 wer 0 gold አሪፍ:3 hyp አሪፍ:3 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 1 wer 1 gold የተወዳደርኩበትን ቀን ነው:16 hyp የተወዳደርኩበትን ቀን ቀው:16
# [1] cer 0 wer 0 gold ምንም አዲስ ነገር የለም:15 hyp ምንም አዲስ ነገር የለም:15 SUCCESS
# [2] cer 1 wer 1 gold አዎ እንደዚያ አደርገዋለሁ:16 hyp አዎ የንደዚያ አደርገዋለሁ:16
# [3] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [4] cer 1 wer 1 gold እና አልተገናኛችሁም:12 hyp እና አልተገናኛችሁምም:13
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold እሺ በቃ አሀ:8 hyp እሺ በቃ አሀ:8 SUCCESS
# [1] cer 0 wer 0 gold ግሩምም የለ:7 hyp ግሩምም የለ:7 SUCCESS
# [2] cer 0 wer 0 gold ምን ብዬሽ እጠይቃታለሁ እኔ:17 hyp ምን ብዬሽ እጠይቃታለሁ እኔ:17 SUCCESS
# [3] cer 0 wer 0 gold ያው አለ አይደለ:10 hyp ያው አለ አይደለ:10 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 2 gold ሪዛይን ዛሬ አገኛታለሁ:14 hyp ሪዛይን ዛሬ አገኛታ ሁ:14
# [1] cer 2 wer 2 gold አካውንቲንግ ነው የሚያጠናው አዎ:20 hyp አካውንቲንግ ነው አሚያጠውአዎ:18
# [2] cer 0 wer 0 gold ምን:2 hyp ምን:2 SUCCESS
# [3] cer 0 wer 0 gold መስከረም ላይ:8 hyp መስከረም ላይ:8 SUCCESS
# [4] cer 3 wer 2 gold አይ ጥሩ ነው እሺ:11 hyp አይ አሮ ነው ይሺ:11
# [5] cer 4 wer 3 gold እዛ እያወራሁ:8 hyp ሥዛ እን ውሁ:8
# [6] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold እ አዎ ልክ ነሽ:10 hyp እ አዎ ልክ ነሽ:10 SUCCESS
# [1] cer 1 wer 1 gold አዎ እናረጋለን:9 hyp አዎ እናረየለን:9
# [2] cer 0 wer 0 gold ታዲያ በእረፍት ጊዜ:12 hyp ታዲያ በእረፍት ጊዜ:12 SUCCESS
# [3] cer 2 wer 3 gold የደጋ በግ ይዘህ ገባሀ:14 hyp የደጋዜበግ ይዘህ ገባ:13
# [4] cer 0 wer 0 gold ኦኬ አይ በቃ:8 hyp ኦኬ አይ በቃ:8 SUCCESS
# [5] cer 0 wer 0 gold አዎ አሚታ መጣች:10 hyp አዎ አሚታ መጣች:10 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ ሄሎ:5 hyp ሄሎ ሄሎ:5 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold የቀረ ያላየኸው አለ:12 hyp የቀረ ያላየኸው አለ:12 SUCCESS
# [1] cer 0 wer 0 gold ሕልም ማለት:7 hyp ሕልም ማለት:7 SUCCESS
# [2] cer 1 wer 2 gold አማን ነው አለሁልህ:12 hyp አማን ነው አለሁ ህ:12
# [3] cer 0 wer 0 gold እየበረታችሁ ነው:10 hyp እየበረታችሁ ነው:10 SUCCESS
# [4] cer 0 wer 0 gold አዎ እሱማ አያዋጣም:12 hyp አዎ እሱማ አያዋጣም:12 SUCCESS
# [5] cer 1 wer 1 gold አዎ መጣ:5 hyp አር መጣ:5
# [6] cer 0 wer 0 gold እ እ እ:5 hyp እ እ እ:5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እ ሄሎ:4 hyp እ ሄሎ:4 SUCCESS
# [1] cer 0 wer 0 gold ደህና ናቸው:7 hyp ደህና ናቸው:7 SUCCESS
# [2] cer 1 wer 1 gold ኧረ አለሁኝ እንደዚህ ይዘጋል:18 hyp ኧረ አለሁኝ እንደዚህ ይዘህል:18
# [3] cer 0 wer 0 gold ምን አልከኝ ምን አልከኝ:15 hyp ምን አልከኝ ምን አልከኝ :16
# [4] cer 2 wer 1 gold አዎ ንፅህናዋን:9 hyp አዎ ንንንናዋን:9
# [5] cer 0 wer 0 gold ጭራሽ:3 hyp ጭራሽ:3 SUCCESS
# [6] cer 0 wer 0 gold ሰለቼሽ:4 hyp ሰለቼሽ:4 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold በዚህ ዐመት:7 hyp በዚህ ዐመት:7 SUCCESS
# [1] cer 0 wer 0 gold በሀያ ሰብለ:7 hyp በሀያ ሰብለ:7 SUCCESS
# [2] cer 0 wer 0 gold አዎ እሑድ እ:8 hyp አዎ እሑድ እ:8 SUCCESS
# [3] cer 1 wer 1 gold በቃ ሰው አጉርሺ በያታ:14 hyp በቃ ሰው አጉርሺ በያ:13
# [4] cer 0 wer 0 gold በሊ:2 hyp በሊ:2 SUCCESS
# [5] cer 0 wer 0 gold ይሻለዋል:5 hyp ይሻለዋል:5 SUCCESS
# [6] cer 0 wer 0 gold ሁሉም ደህና ናቸው:11 hyp ሁሉም ደህና ናቸው:11 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold አንብቤያለሁ ምንም የለም:15 hyp አንብቤያለሁ ምንም የለም:15 SUCCESS
# [1] cer 1 wer 1 gold አደጉ እንደት ናቸው:12 hyp አደጉ እንደት ነቸው:12
# [2] cer 0 wer 0 gold ኧረ ውላ ነው የምትሄደው:15 hyp ኧረ ውላ ነው የምትሄደው:15 SUCCESS
# [3] cer 0 wer 0 gold ኧረ እባክሽ:7 hyp ኧረ እባክሽ:7 SUCCESS
# [4] cer 0 wer 0 gold አሀ እንደዚያ ነው:11 hyp አሀ እንደዚያ ነው:11 SUCCESS
# [5] cer 0 wer 0 gold እኮ በአስራ ስድስት:12 hyp እኮ በአስራ ስድስት:12 SUCCESS
# [6] cer 0 wer 0 gold ቀደም ብለሽ ገዛሽ:11 hyp ቀደም ብለሽ ገዛሽ:11 SUCCESS
# [7] cer 0 wer 0 gold እግዚአብሔር ያ:9 hyp እግዚአብሔር ያ:9 SUCCESS
# [0] cer 2 wer 1 gold ኳስ አሁንም ትጫወታላችሁ እንደ:19 hyp ኳስ አሁንም ምጫወታችችሁ እንደ:19
# [1] cer 1 wer 1 gold እ አይ:4 hyp እ አ:3
# [2] cer 1 wer 1 gold እ ንገረኝ:6 hyp እ ንለረኝ:6
# [3] cer 0 wer 0 gold እየፆምክ ነው እንደ አንተ:16 hyp እየፆምክ ነው እንደ አንተ:16 SUCCESS
# [4] cer 0 wer 0 gold እንደ በጣም ከባድ ነው:14 hyp እንደ በጣም ከባድ ነው:14 SUCCESS
# [5] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [6] cer 0 wer 0 gold አዎ የ :5 hyp አዎ የ :5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 9 wer 3 gold አማራ አይሻልህም ሱማሌ ይሻልሀል:20 hyp አማራ አይሻልምምምሱሀልማሱማልሀሀሀ:21
# [1] cer 2 wer 1 gold በሚቀጥለው ዐመት ትጀምራለህ:17 hyp በሚቀጥለው ዐመት ትጀለራህህ:17
# [2] cer 1 wer 1 gold አዲስ ነገር አዲስ ነገር:15 hyp አዲስ ነገር አዲስ ወገር:15
# [3] cer 0 wer 0 gold አለመመቻቸት ፈተና:11 hyp አለመመቻቸት ፈተና:11 SUCCESS
# [4] cer 0 wer 0 gold አሀ:2 hyp አሀ:2 SUCCESS
# [5] cer 1 wer 1 gold አሁን አየሁኝ አዎ:11 hyp አሁን አዎሁኝ አዎ:11
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 5 wer 3 gold አይ አልደወልኩም ቆይቻለሁ ከደወልኩኝ:23 hyp አይ አለደወልምም ከይቻቻሁከደወደኩኝ:22
# [1] cer 2 wer 1 gold አላመነኝም በደንብ ባለፈው:16 hyp አላመነኝም በደንብ ባለውውባ:17
# [2] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [3] cer 0 wer 0 gold ምክንያቱ ምንድን ነው:13 hyp ምክንያቱ ምንድን ነው:13 SUCCESS
# [4] cer 0 wer 0 gold ትበላለህ:5 hyp ትበላለህ:5 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold ምን አልሽ:6 hyp ምን አልሽ:6 SUCCESS
# [0] cer 0 wer 0 gold ቀረፃ አለው:7 hyp ቀረፃ አለው:7 SUCCESS
# [1] cer 0 wer 0 gold አንቺማ ትከታተያለሽ መሰለኝ:17 hyp አንቺማ ትከታተያለሽ መሰለኝ:17 SUCCESS
# [2] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [3] cer 0 wer 0 gold እስካሁን አልደወሉም እኮ:15 hyp እስካሁን አልደወሉም እኮ:15 SUCCESS
# [4] cer 0 wer 0 gold አንዳንዴ:5 hyp አንዳንዴ:5 SUCCESS
# [5] cer 0 wer 0 gold በ :2 hyp በ :2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እሺ እንደት ነው:10 hyp እሺ እንደት ነው:10 SUCCESS
# [1] cer 0 wer 0 gold ያው:2 hyp ያው:2 SUCCESS
# [2] cer 0 wer 0 gold እኮ አዎ:5 hyp እኮ አዎ:5 SUCCESS
# [3] cer 6 wer 4 gold አዎ እዛ ሄደን ትንሽ:13 hyp አለ አዛ ደደንነ:10
# [4] cer 2 wer 2 gold ኦኬ ለሁለተኛው:9 hyp ኦኬ ለሁ ተውው :10
# [5] cer 0 wer 0 gold ምን መሰለህ:7 hyp ምን መሰለህ:7 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 2 wer 2 gold አላየሁም ማታ በዘፈቀ አሜሪካ:18 hyp አላየሁም ማታ በዘህቀ አሜካካ:18
# [1] cer 0 wer 0 gold እሺ እማዬ:6 hyp እሺ እማዬ:6 SUCCESS
# [2] cer 0 wer 2 gold አዎ እንደ እሱ ብሏል:13 hyp አዎ እንደ እሱብሏል:12
# [3] cer 0 wer 0 gold እንደ እሺ:6 hyp እንደ እሺ:6 SUCCESS
# [4] cer 0 wer 0 gold የት አገኘኸው:8 hyp የት አገኘኸው:8 SUCCESS
# [5] cer 0 wer 0 gold ሰብለ እንደት ናት:11 hyp ሰብለ እንደት ናት:11 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እንደት ነህ:7 hyp እንደት ነህ:7 SUCCESS
# [1] cer 0 wer 0 gold ኪራይ አይደለም እንደ:13 hyp ኪራይ አይደለም እንደ:13 SUCCESS
# [2] cer 3 wer 2 gold አንድ ወንድ ኦኬ እሺ:13 hyp አንድ ወን  ኦኬ ኦሺኦ:14
# [3] cer 1 wer 1 gold ጥናት ጥናት እንደት ነው:15 hyp ጥናት ጥናት ደንደት ነው:15
# [4] cer 0 wer 0 gold ይጠራሻል:5 hyp ይጠራሻል:5 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold ስማ:2 hyp ስማ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 3 wer 2 gold ስንት ቁጥር ነው ወገብህ:15 hyp በንት ቁጥር ነው ወብናህ:15
# [1] cer 1 wer 1 gold ድምፅሽ ይቆራረጣል አይሰማም:17 hyp ድምፅሽ ይቆራልጣል አይሰማም:17
# [2] cer 0 wer 0 gold አዎ እሄዳለሁ:8 hyp አዎ እሄዳለሁ:8 SUCCESS
# [3] cer 0 wer 0 gold ኤልሳ ትደውላለች አይደል:15 hyp ኤልሳ ትደውላለች አይደል:15 SUCCESS
# [4] cer 1 wer 1 gold ምን አለበት:7 hyp ምን አለትት:7
# [5] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 3 wer 2 gold አመነ አ እንደሚሸነፍ እ:15 hyp አመነ አ ሸንሸሚሸነፍ መ:15
# [1] cer 0 wer 0 gold ታካክሺዋለሽ:7 hyp ታካክሺዋለሽ:7 SUCCESS
# [2] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [3] cer 1 wer 1 gold አትመጭም:5 hyp አቤመጭም:5
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold ሸጋ ነው:5 hyp ሸጋ ነው:5 SUCCESS
# [1] cer 3 wer 4 gold እንዳትጨናነቂ ችግር የለውም:17 hyp ችንዳትጨናነቂ ች ር የለውምም:18
# [2] cer 1 wer 1 gold እ ብር የለኝም:9 hyp እ ብር የለኝምም:10
# [3] cer 1 wer 1 gold ኧረ ሩጫው እንደት ነበር:15 hyp ኧረ ሩጫው ነንደት ነበር:15
# [4] cer 0 wer 0 gold እኮ ምን ጀመርክ:10 hyp እኮ ምን ጀመርክ:10 SUCCESS
# [5] cer 0 wer 0 gold አወያይሻለሁ:7 hyp አወያይሻለሁ:7 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold አዎ ሦስት ሦስት ለአንድ:15 hyp አዎ ሦስት ሦስት ለአንድ:15 SUCCESS
# [1] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [2] cer 0 wer 0 gold ወሰንዬ ሰላም ነሽ:11 hyp ወሰንዬ ሰላም ነሽ:11 SUCCESS
# [3] cer 0 wer 0 gold ሀንዬ ምንድን ነው ነገሩ:15 hyp ሀንዬ ምንድን ነው ነገሩ:15 SUCCESS
# [4] cer 1 wer 1 gold አዎ ቀላል እንዳይመስልሽ:15 hyp አዎ ቀላል እንዳይመስመሽ:15
# [5] cer 1 wer 1 gold ገራሚ:3 hyp የራሚ:3
# [6] cer 2 wer 2 gold አሁን እየለመድኩ ነው:13 hyp አበን እየለመኝኩ ነው:13
# [7] cer 0 wer 0 gold እየተሻላቸው ነው አ:12 hyp እየተሻላቸው ነው አ:12 SUCCESS
# [0] cer 1 wer 1 gold ተከታዪን ቤቢን እየቀዘነ ስለሆነ:20 hyp ተከታዪን ቤቢን እየቀዘነ ስረሆነ:20
# [1] cer 2 wer 1 gold ለነገሩ ባየም ስለሚወራረድ እ:18 hyp ለነገሩ ባየም ስለህወራረ  እ:18
# [2] cer 1 wer 1 gold ሰላም ነው ሰላም ነው:13 hyp ሰላም ነው ሰኩም ነው:13
# [3] cer 0 wer 0 gold ምን ዲፓርትመንት:10 hyp ምን ዲፓርትመንት:10 SUCCESS
# [4] cer 1 wer 1 gold ኦኬ አራት ሰዐት ተኩል:14 hyp ኦኬ አዎት ሰዐት ተኩል:14
# [5] cer 0 wer 0 gold እንደት ነው ሰላም ነው:14 hyp እንደት ነው ሰላም ነው:14 SUCCESS
# [6] cer 0 wer 0 gold ምን:2 hyp ምን:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold ምኑን ነው የተዋችሁት:13 hyp ምኑን ነው የተዋችሁትት:14
# [1] cer 3 wer 4 gold የማህበር ስለሆነ ማለት እ:16 hyp የማህበር ስለ ነ ማለህ የ:16
# [2] cer 0 wer 0 gold አንተስ ሰላም ነህ:11 hyp አንተስ ሰላም ነህ:11 SUCCESS
# [3] cer 2 wer 1 gold ሄሎ ይቆራረጣል:9 hyp ሄሎ ይቆራል:7
# [4] cer 5 wer 3 gold አዚዛስ ደህና ናት ባለቤትህ:17 hyp አዚዛስ ብህና አነ ባለቤለ:16
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እንደ እሱ ይሻላል:11 hyp እንደ እሱ ይሻላል:11 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold በቃ እሺ እነግራታለሁ:13 hyp በቃ እሺ እነግራለለሁ:13
# [1] cer 3 wer 2 gold በሚቀጥለው ዐመት ነው የሚመረቀው:20 hyp በሚቀጥለው ዐመት የው ቀሚቀረቀው:20
# [2] cer 0 wer 0 gold እንደት ነሽ አዎ በጣም:14 hyp እንደት ነሽ አዎ በጣም:14 SUCCESS
# [3] cer 0 wer 0 gold በስመ አብ:6 hyp በስመ አብ:6 SUCCESS
# [4] cer 0 wer 0 gold እኛ እንዳደግነው ይደግ ነው:17 hyp እኛ እንዳደግነው ይደግ ነው:17 SUCCESS
# [5] cer 0 wer 0 gold ጣራው ላይ:6 hyp ጣራው ላይ:6 SUCCESS
# [6] cer 0 wer 0 gold አንቺ እንዴ :8 hyp አንቺ እንዴ :8 SUCCESS
# [7] cer 0 wer 0 gold ይርቃል:4 hyp ይርቃል:4 SUCCESS
# [0] cer 0 wer 0 gold ምናምን ደህና ናቸው በተረፈ:17 hyp ምናምን ደህና ናቸው በተረፈ:17 SUCCESS
# [1] cer 1 wer 2 gold አይደል አዎ:7 hyp አለደልአዎ:6
# [2] cer 2 wer 2 gold አላገባም እስካሁን እንኳን:16 hyp አላገባም እስካሁ  ወንኳን:16
# [3] cer 0 wer 0 gold ቤት ነች ምንም:9 hyp ቤት ነች ምንም:9 SUCCESS
# [4] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 4 wer 3 gold አዎ አይ ይሻላል እንደዚያ:16 hyp አዎ አይሻአሻላል አንደያያ:16
# [1] cer 1 wer 1 gold እኮ ከሰዐት ትመጣለህ:13 hyp እኮ ከሰዐል ትመጣለህ:13
# [2] cer 1 wer 2 gold ኧረ በእውነት በይ:11 hyp ኧረ በእ ነት በይ:11
# [3] cer 1 wer 1 gold ሄሎ አይሰማህም:9 hyp ሄሎ አይሰማህምም:10
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ ሄሎ:5 hyp ሄሎ ሄሎ:5 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold ምን ልበልህ ጉዞ እ:12 hyp ምን ልበልህ ጉዞ እ:12 SUCCESS
# [1] cer 0 wer 0 gold እኔም የዚያኑ ይዤ ነው:14 hyp እኔም የዚያኑ ይዤ ነው:14 SUCCESS
# [2] cer 1 wer 1 gold አዎ በተረፈ ሰላም ነሽ:14 hyp አዎ በተላፈ ሰላም ነሽ:14
# [3] cer 0 wer 0 gold ይሰማኛል ይሰማኛል:11 hyp ይሰማኛል ይሰማኛል:11 SUCCESS
# [4] cer 0 wer 0 gold አዎ ምንም አይደለም:12 hyp አዎ ምንም አይደለም:12 SUCCESS
# [5] cer 0 wer 0 gold ጠፋች:3 hyp ጠፋች:3 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 1 wer 1 gold አይ የእና :7 hyp አይ የእየ :7
# [0] cer 2 wer 1 gold እ እንትን አልደወልኩለትም:16 hyp እ እንትን አልደወልኩምም:15
# [1] cer 1 wer 1 gold መች ነው የምትመጪው:12 hyp መች ነው የምመመጪው:12
# [2] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [3] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ ሲራክ:6 hyp ሄሎ ሲራክ:6 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 2 gold ኧረ አስቤዋለሁ አስቤዋለሁ:16 hyp ኧረ አንቤዋለሁ አስቤዋቤሁ:16
# [1] cer 0 wer 0 gold ይቆራረጣል እ:8 hyp ይቆራረጣል እ:8 SUCCESS
# [2] cer 3 wer 2 gold እ አስር ደቂቃው አልሞላም:16 hyp እ አስር ምቂቃው አለሞምም:16
# [3] cer 2 wer 2 gold እኮ ያስ እንደት ነው:13 hyp እኮ ምስ ይንደት ነው:13
# [4] cer 0 wer 0 gold አይመችም:5 hyp አይመችም:5 SUCCESS
# [5] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ሁሉም ሰላም ነው:10 hyp ሁሉም ሰላም ነው:10 SUCCESS
# [1] cer 2 wer 2 gold ስንት ይሰጧቸዋል በወር ቢያንስ:19 hyp ስንት ይሰጧቸዋል ቢወርንቢያንስ:19
# [2] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [3] cer 2 wer 1 gold አይ ሽንኩርት ምናምንሳ:14 hyp አይ ሽንኩርት ምምምሳ:13
# [4] cer 0 wer 0 gold አልጠየኳትም:7 hyp አልጠየኳትም:7 SUCCESS
# [5] cer 0 wer 0 gold በግ ይሻልሀል:8 hyp በግ ይሻልሀል:8 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold ለመከራ የፈጠረኝ:10 hyp ምመከራ የፈጠረኝ:10
# [1] cer 0 wer 0 gold ለእዛ ነው እ:8 hyp ለእዛ ነው እ:8 SUCCESS
# [2] cer 1 wer 1 gold ፏ አሁን ይሰማኛል:11 hyp ፏ አሁን አሰማኛል:11
# [3] cer 1 wer 1 gold ልዘጋው ነው ስልኩን:12 hyp ልዘጋው ነው ስልኩህ :13
# [4] cer 0 wer 0 gold እሺ ምን:5 hyp እሺ ምን:5 SUCCESS
# [5] cer 0 wer 0 gold አይደለ:4 hyp አይደለ:4 SUCCESS
# [6] cer 0 wer 0 gold አለ:2 hyp አለ:2 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 2 wer 2 gold ሁሉንም እንደው ሰላም በይልኝ:18 hyp ሁሉንም እንደው ናላምኝበይልኝ:18
# [1] cer 1 wer 1 gold እሺ ከደበረህ እተወዋለሁ:15 hyp እሺ ከደበርህ እተወዋለሁ:15
# [2] cer 2 wer 2 gold እ ትመጣለች ነገ:10 hyp በ ትመጣችች ነገ:10
# [3] cer 1 wer 1 gold ደህና ናቸው እ:9 hyp ደህና ናቸው ደ:9
# [4] cer 0 wer 0 gold ሥራ ጀምሯል ወይስ:11 hyp ሥራ ጀምሯል ወይስ:11 SUCCESS
# [5] cer 1 wer 1 gold ቤተሰብ ምናምን:9 hyp ቤተሰብ ምናም:8
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold መሳፍንት ገጠር ሄዷል ሰሞኑን:18 hyp መሳፍንት ገጠር ሄዷል ሰሞኑን:18 SUCCESS
# [1] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [2] cer 0 wer 0 gold መቼ ነው መቼ ነው:11 hyp መቼ ነው መቼ ነው:11 SUCCESS
# [3] cer 1 wer 2 gold እ ቤተሰብ ሰላም ነው:13 hyp እ ቤተ ብ ሰላም ነው:13
# [4] cer 1 wer 1 gold አሁን ይሰማኛል:9 hyp አሁን ይሰማምል:9
# [5] cer 0 wer 0 gold አይሰማም:5 hyp አይሰማም:5 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እሺ ችግር የለም:10 hyp እሺ ችግር የለም:10 SUCCESS
# [1] cer 0 wer 0 gold እሺ በቃ በኋላ:9 hyp እሺ በቃ በኋላ:9 SUCCESS
# [2] cer 2 wer 3 gold ይደውላል ትገናኛላችሁ አይደል:18 hyp ይደውላል ትገናኛ ችሁ አድደል:18
# [3] cer 0 wer 0 gold ኧረ አንቺ ነሽ:9 hyp ኧረ አንቺ ነሽ:9 SUCCESS
# [4] cer 1 wer 1 gold እግዚአብሔር ይመስገን ደህና አደርሽ:22 hyp እግዚአብሔር ይመስገን ደህና ደደርሽ:22
# [5] cer 0 wer 0 gold እሱማ አዎ አዎ:9 hyp እሱማ አዎ አዎ:9 SUCCESS
# [6] cer 1 wer 1 gold ሰላም ናችሁ እናንተም:13 hyp ሰላም ናችሁ እናንናም:13
# [7] cer 0 wer 0 gold የት:2 hyp የት:2 SUCCESS
# [0] cer 0 wer 0 gold ሄሎ ሄሎ እ ማርታ:11 hyp ሄሎ ሄሎ እ ማርታ:11 SUCCESS
# [1] cer 0 wer 0 gold ለ:1 hyp ለ:1 SUCCESS
# [2] cer 1 wer 1 gold እኮ አዎ ግድ ነው:11 hyp አኮ አዎ ግድ ነው:11
# [3] cer 1 wer 1 gold ግብዳ ነው አይደል:11 hyp መብዳ ነው አይደል:11
# [4] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold ጆን:2 hyp ጆን:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 2 gold ለነገሩ አዎ አንተ ዲፓርትመንት:19 hyp ለነገሩ አን አንተ ዲፓርትንት:18
# [1] cer 6 wer 2 gold አዎ መሀል ላይ ይቆራረጣል:16 hyp አዎ መታታ ላይ ይታዋልልል:16
# [2] cer 1 wer 1 gold እስኪ አንዳንድ ወሬ አምጪ:16 hyp እስኪ አንዳን  ወሬ አምጪ:16
# [3] cer 1 wer 1 gold በቃ ደውል:6 hyp በቃ ደው :6
# [4] cer 1 wer 1 gold ትናንት አላየኸውም:11 hyp ትናንት አላየኸውምም:12
# [5] cer 0 wer 0 gold ኦ ይቴ:4 hyp ኦ ይቴ:4 SUCCESS
# [6] cer 0 wer 0 gold ቴዲ ነህ እ:7 hyp ቴዲ ነህ እ:7 SUCCESS
# [7] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [0] cer 1 wer 1 gold እ ዊ አዎ ስለዚህ:11 hyp እ ዊ አዎ ስለዚዚ:11
# [1] cer 0 wer 0 gold አለሁ ሰላም ነው አለሁ:14 hyp አለሁ ሰላም ነው አለሁ:14 SUCCESS
# [2] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [3] cer 0 wer 0 gold እኮ:2 hyp እኮ:2 SUCCESS
# [4] cer 2 wer 1 gold መት  ሳላገኛት:9 hyp መት  ሳላኛትት:9
# [5] cer 0 wer 0 gold የችፑዱ:4 hyp የችፑዱ:4 SUCCESS
# [6] cer 0 wer 0 gold በእውነት:5 hyp በእውነት:5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 1 gold ማ  ማሙሽስ ይደውልለታል:15 hyp ማ  ማሙሽስ ይደውልልታልል:16
# [1] cer 0 wer 0 gold አዎ ለእዛም ነው:10 hyp አዎ ለእዛም ነው :11
# [2] cer 1 wer 1 gold እ አሸናፊ ጋር:9 hyp እ አሸፊፊ ጋር:9
# [3] cer 4 wer 4 gold አሀ አዎ ጓደኛሽ ነች:13 hyp አካ አዎልጓግኛሽ ነው:13
# [4] cer 1 wer 1 gold የምን አልተመቸውም:11 hyp የምን አልተመቸው:10
# [5] cer 0 wer 0 gold ልዩነት የለውም:9 hyp ልዩነት የለውም:9 SUCCESS
# [6] cer 0 wer 0 gold አለሁልህ:5 hyp አለሁልህ:5 SUCCESS
# [7] cer 0 wer 0 gold ሊጋባው:4 hyp ሊጋባው:4 SUCCESS
# [0] cer 1 wer 1 gold ቅዳሜ እና እሑድ:10 hyp ቅዳሜ ድና እሑድ:10
# [1] cer 0 wer 0 gold ዛሬ የለም:6 hyp ዛሬ የለም:6 SUCCESS
# [2] cer 0 wer 0 gold አዎ ብያለሁ እንግዲህ:13 hyp አዎ ብያለሁ እንግዲህ:13 SUCCESS
# [3] cer 0 wer 0 gold አይ እሱማ:6 hyp አይ እሱማ:6 SUCCESS
# [4] cer 0 wer 0 gold እንደዚያ ነው:8 hyp እንደዚያ ነው:8 SUCCESS
# [5] cer 0 wer 0 gold እየበላሁ ነው:8 hyp እየበላሁ ነው:8 SUCCESS
# [6] cer 0 wer 0 gold እንደት ነበ :8 hyp እንደት ነበ :8 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 3 gold ልጅህ ስንተኛ ክፍል ደረሰ:16 hyp ልጅህ ስን ኛ ክፍል ይረሰ:16
# [1] cer 3 wer 3 gold እኔ ምንም አልል ይደውላሉ:16 hyp እኔ ምን  ኧልል ይደውላሉላ:17
# [2] cer 1 wer 1 gold በቃ እማማንም ይዘሻት ትምጫለሽ:19 hyp በቃ እማማንም ይዘሻት ትጫጫለሽ:19
# [3] cer 0 wer 0 gold እነ አበባ:6 hyp እነ አበባ:6 SUCCESS
# [4] cer 0 wer 0 gold ይሰማል ይሰማል:9 hyp ይሰማል ይሰማል:9 SUCCESS
# [5] cer 2 wer 2 gold ኧረ ዝም በል:8 hyp አረ ዝም ተል:8
# [6] cer 1 wer 1 gold ምን ብዬሽ ልንገራቸው:13 hyp ምን ብዬሽ ልንገቸቸው:13
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 5 wer 4 gold የጎንደር አካባቢ ንግግር ነው:18 hyp እጎንደር አካ ቢ ነግግርትነግ:18
# [1] cer 0 wer 0 gold አቤት ይሰማኛል አዎ አዎ:15 hyp አቤት ይሰማኛል አዎ አዎ:15 SUCCESS
# [2] cer 0 wer 0 gold የባለፈው:5 hyp የባለፈው:5 SUCCESS
# [3] cer 0 wer 0 gold ያ:1 hyp ያ:1 SUCCESS
# [4] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 1 wer 2 gold ኧረ ወስዷል ወስዷል ወስዷል:17 hyp ኧረ ወስዷልምወስዷል ወስዷል:17
# [1] cer 6 wer 4 gold አይ ዝም ብሎ እየቀዘነ:14 hyp አል አምንብሎምአየቀምነ:14
# [2] cer 2 wer 1 gold እና ዛሬ አትጋብዘኝም:13 hyp እና ዛሬ አላጋብዘኝምም:14
# [3] cer 0 wer 0 gold አዎ እ:4 hyp አዎ እ:4 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold አሀ ብሎ ማለት ነው:12 hyp አሀ ብሎ ማለት ነው:12 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold አዎ እስኪ ምንም:10 hyp አዎ እሄኪ ምንም:10
# [1] cer 0 wer 0 gold ስንት ዐመቷ ሆናት:11 hyp ስንት ዐመቷ ሆናት:11 SUCCESS
# [2] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [3] cer 3 wer 2 gold አይ እሱ ካለም:9 hyp አይ አሱ አለ  :10
# [4] cer 0 wer 0 gold አይሰማም:5 hyp አይሰማም:5 SUCCESS
# [5] cer 0 wer 0 gold ፋሲል:3 hyp ፋሲል:3 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 1 wer 1 gold አዎ አዎ አዎ አዟችሁ:13 hyp አዎ አዎ አዎ አዎችሁ:13
# [1] cer 1 wer 1 gold እሺ እ ሌላስ:8 hyp ጥሺ እ ሌላስ:8
# [2] cer 1 wer 1 gold ዛሬ አይተኸዋል እሱን ሀብቱን:18 hyp ዛሬ አይተኸዋል እሱን ሀብቱንን:19
# [3] cer 3 wer 3 gold አሁን ቀንሷል አይደል:13 hyp ሰሁን ቀለሷል አይደልም:14
# [4] cer 1 wer 1 gold አለሁ እንደት ነው:11 hyp አለሁ እንደት አው:11
# [5] cer 2 wer 1 gold መቼ ነው እምትጀምሩት:13 hyp መቼ ነው እምትጀምሩሩሩ:14
# [6] cer 0 wer 0 gold ሰላም ናት:6 hyp ሰላም ናት:6 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold ሥራ እዛው ናቸው:10 hyp ሥራ እዛው ናቸው:10 SUCCESS
# [1] cer 0 wer 0 gold ምነው እ:5 hyp ምነው እ:5 SUCCESS
# [2] cer 0 wer 0 gold ምን ምን ሰራችሁ:10 hyp ምን ምን ሰራችሁ:10 SUCCESS
# [3] cer 2 wer 1 gold በቃ የፍ  ፍፁም:10 hyp በቃ የፍ የየፁም :11
# [4] cer 0 wer 0 gold ፒስ ነው ምን አልከኝ:13 hyp ፒስ ነው ምን አልከኝ:13 SUCCESS
# [5] cer 0 wer 0 gold ኦኬ:2 hyp ኦኬ:2 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold ስልስ:3 hyp ስልስ:3 SUCCESS
# [0] cer 3 wer 3 gold ሄሎ አይሰማም አይሰማምሽም ወይ:19 hyp ሄሎ ሄይሰማም አይሰማምሽሽሽወይ:19
# [1] cer 4 wer 3 gold አዎ ሁለት ወር ነው:12 hyp አዎ ሁሁን አር አው:12
# [2] cer 0 wer 0 gold አሁን እኮ:6 hyp አሁን እኮ:6 SUCCESS
# [3] cer 1 wer 1 gold ማንን ነው ነው የምልሽ:14 hyp ማንን ነው ነው የምሽሽ:14
# [4] cer 0 wer 0 gold እየሰራሽ ነው አ:10 hyp እየሰራሽ ነው አ:10 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold አያገኘኝም ያን ስልክ:13 hyp አያገኘኝም ያን ስልክ:13 SUCCESS
# [1] cer 1 wer 1 gold አይሻልም አንድ ላይ:12 hyp እይሻልም አንድ ላይ:12
# [2] cer 1 wer 1 gold ያ ነገር ደግሞ ይከሰታል:15 hyp ያ ነገ  ደግሞ ይከሰታል:15
# [3] cer 0 wer 0 gold ባሌ ደህና ነው:9 hyp ባሌ ደህና ነው:9 SUCCESS
# [4] cer 0 wer 0 gold ክረምት:4 hyp ክረምት:4 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 3 wer 2 gold መቲ ቅድም ደወልኩላት:13 hyp ምቲ ቅድም የወልኩትት:13
# [1] cer 0 wer 0 gold ተመልካቾቹ ብዙ ናቸው ነው:16 hyp ተመልካቾቹ ብዙ ናቸው ነው :17
# [2] cer 1 wer 1 gold አዎ እንዳለ ማንም አላደረም:17 hyp አዎ እንዳለ ማንም አላጠረም:17
# [3] cer 0 wer 0 gold በጣም:3 hyp በጣም:3 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold ሁሉም ሰላም ነው:10 hyp ሁሉም ሰላም ነው:10 SUCCESS
# [6] cer 0 wer 0 gold አንተ:3 hyp አንተ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 5 wer 3 gold ለፈተና ሊጠሯችሁ ይችላሉ እናንተን:21 hyp ለፈተና ሊጠሯችሁ ይች ን ወናን:19
# [1] cer 0 wer 0 gold እሺ እና እንደ እ:11 hyp እሺ እና እንደ እ:11 SUCCESS
# [2] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [3] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [4] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold ሄሎ አስኳል እንደት ነሽ:15 hyp ሄሎ አስኳል እንደም ነሽ:15
# [1] cer 1 wer 1 gold ከእዛ በኋላ:7 hyp ከእዛ በርላ:7
# [2] cer 0 wer 0 gold እ ተቆራረ :7 hyp እ ተቆራረ :7 SUCCESS
# [3] cer 0 wer 2 gold አቤት አቤት እየሰማሁህ ነው:17 hyp አቤት አቤት እየሰማሁ ህነው:17
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold እ እሺ:4 hyp እ እሺ:4 SUCCESS
# [6] cer 0 wer 0 gold እኔ እንጃ:6 hyp እኔ እንጃ:6 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold በቃ እ እ:6 hyp በቃ እ እ:6 SUCCESS
# [1] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [2] cer 3 wer 2 gold ይ  ይደውላል እንደ:12 hyp ይ  ነደውላት እንያ:12
# [3] cer 0 wer 0 gold አሁን ሀቢታት ነሽ እንደ:15 hyp አሁን ሀቢታት ነሽ እንደ:15 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ ሄሎ አቡሼ:9 hyp ሄሎ ሄሎ አቡሼ:9 SUCCESS
# [5] cer 0 wer 0 gold አርባ:3 hyp አርባ:3 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold ሁሉንም ነ :7 hyp ሁሉንም ነ :7 SUCCESS
# [0] cer 4 wer 2 gold አዎ ትናንትናም ደውዬ ነበረ:17 hyp አዎ አንንትናው ደው  ነበረ:17
# [1] cer 2 wer 2 gold የወለደ ከብት የለም እንደው:17 hyp የባለደ ከብት የለም የንደው:17
# [2] cer 0 wer 0 gold እ እ እ:5 hyp እ እ እ:5 SUCCESS
# [3] cer 3 wer 3 gold እና እዛ ትሄጃለሽ:11 hyp እና ሳዛ ነሄጃ ሽ:11
# [4] cer 1 wer 1 gold አዎ ሳይሆን አይቀርም:13 hyp አዎ ሳይሆን አይቀርምም:14
# [5] cer 0 wer 0 gold ጉሬ ነህ:5 hyp ጉሬ ነህ:5 SUCCESS
# [6] cer 0 wer 0 gold አቤት አቤት:7 hyp አቤት አቤት:7 SUCCESS
# [7] cer 0 wer 0 gold ባይስክል:5 hyp ባይስክል:5 SUCCESS
# [0] cer 1 wer 1 gold ስቀው ምናምን ከላይ ሆነው:16 hyp ስቀው ምናምን ከላነ ሆነው:16
# [1] cer 1 wer 2 gold ምን አለበት አንተ በጣም:15 hyp ምን አለ ት አንተ በጣም:15
# [2] cer 1 wer 1 gold ይዘሽ መተሻል ወይ:11 hyp ይዘሽ መተሻል ይይ:11
# [3] cer 0 wer 0 gold እንትን ብር:7 hyp እንትን ብር:7 SUCCESS
# [4] cer 0 wer 0 gold ተመልሶ አይገባማ በቃ:13 hyp ተመልሶ አይገባማ በቃ:13 SUCCESS
# [5] cer 0 wer 0 gold እግዚአብሔርን:8 hyp እግዚአብሔርን:8 SUCCESS
# [6] cer 0 wer 0 gold እንደት ነሽ እግዚአብሔር ይመስገን:21 hyp እንደት ነሽ እግዚአብሔር ይመስገን:21 SUCCESS
# [7] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [0] cer 1 wer 1 gold ያው በየትኛውም:9 hyp ያው በየትኛውምም:10
# [1] cer 2 wer 2 gold ሰሚራ እባክህ ተኮፍሳለች:15 hyp ሰሚራ እባክህ ተኮፍ ለ:14
# [2] cer 0 wer 0 gold በቃ አሁን ሲመጣ ነዋ:13 hyp በቃ አሁን ሲመጣ ነዋ:13 SUCCESS
# [3] cer 0 wer 0 gold እ እ እ እ:7 hyp እ እ እ እ:7 SUCCESS
# [4] cer 1 wer 1 gold አቤት አይሰማሽም:10 hyp አቤት አይሰማሽምም:11
# [5] cer 0 wer 0 gold ትገናኛላችሁ:7 hyp ትገናኛላችሁ:7 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold ታዲያ:3 hyp ታዲያ:3 SUCCESS
# [0] cer 0 wer 0 gold አይ ጥሩ ነው:8 hyp አይ ጥሩ ነው:8 SUCCESS
# [1] cer 7 wer 4 gold አ አግብተህ ተጠቅልላ ታዲያ:17 hyp በ አዎብተጠ ተጠቅ   ታና:16
# [2] cer 1 wer 1 gold አዎ መቼም አናገኘውም:13 hyp አዎ መቼም አናገኘም  :14
# [3] cer 2 wer 2 gold አዎ ሥራ አለ:8 hyp አዎ ሥማማአለ:8
# [4] cer 0 wer 0 gold አልደወለችም:7 hyp አልደወለችም:7 SUCCESS
# [5] cer 0 wer 0 gold ሰላም ነው:6 hyp ሰላም ነው:6 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [1] cer 0 wer 0 gold ሄሎ ሄሎ ሄሎ ሄሎ:11 hyp ሄሎ ሄሎ ሄሎ ሄሎ:11 SUCCESS
# [2] cer 0 wer 0 gold እ ሄሎ:4 hyp እ ሄሎ:4 SUCCESS
# [3] cer 1 wer 1 gold አዎ በጣም እየተመቸኝ ነው:16 hyp አዎ በጣም የየተመቸኝ ነው:16
# [4] cer 1 wer 1 gold በጠበጠች:5 hyp በጠጠጠች:5
# [5] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 4 wer 3 gold ኧረ እንደው አላገባም ምናምን:18 hyp ኧረ ምንው አላገምም ምናምንን:18
# [1] cer 2 wer 2 gold ተፈተንልኝ እኔ አልሄድም:15 hyp ይፈተንልኝ እኔ አልድድም:15
# [2] cer 3 wer 2 gold አዎ የግድ ነው እሱማ:13 hyp አዎ የግድ ነውማአሱ:12
# [3] cer 2 wer 2 gold ያው ሰፈር ነዋ የምንገናኘው:17 hyp ያው ሰቃር ነዋ የምንናናኘው:17
# [4] cer 3 wer 3 gold ሰፊ የሚቆይ ሥራ ነው:13 hyp አፊ የሚቆ  አራ ነው:13
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold ኦኬ እኛን አይፈልገንም:14 hyp ኦኬ እኛን አይፈልገን:13
# [1] cer 1 wer 1 gold በጭማሬው ነው የሚከፈላቸው አሁን:20 hyp በጭማሬው ነው የሚከፈቸቸው አሁን:20
# [2] cer 0 wer 0 gold አዎ ኤደንዬ:7 hyp አዎ ኤደንዬ:7 SUCCESS
# [3] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [4] cer 0 wer 0 gold አሀ:2 hyp አሀ:2 SUCCESS
# [5] cer 0 wer 0 gold ደህና ነች:6 hyp ደህና ነች:6 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 10 wer 5 gold ብቻዬን እንደማልሄድ ስለሚያውቅ ይጠራ :24 hyp ብቻዬ  እን ማል ድ ቅጠሁያጠቅጠራሁቅ:23
# [1] cer 3 wer 3 gold እሷ እያፅናናችሽ ነው እንጂ:17 hyp እሷ እያፅናና ሽ ነውነሰጂ:16
# [2] cer 2 wer 3 gold ሪዛይን አገኛታለሁ ብዬሽ አስቤያለሁ:22 hyp ሪዛይን አገኛታለሁምብዬሽ አስቤያሽሁ :23
# [3] cer 2 wer 2 gold አዎ ሥራ ላይ እ:10 hyp አዎ ሥራ ቅይ ነ:10
# [4] cer 1 wer 1 gold አይ ችግር የለውም:11 hyp አይ ችግር የለው:10
# [5] cer 0 wer 0 gold ኧ:1 hyp ኧ:1 SUCCESS
# [6] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold አንዳንዴም እንደው እ:13 hyp አንዳንዴም እንደው እ:13 SUCCESS
# [1] cer 1 wer 1 gold ትምህርት ቆንጆ ነው:12 hyp እምህርት ቆንጆ ነው:12
# [2] cer 0 wer 0 gold ጤናውን እ:6 hyp ጤናውን እ:6 SUCCESS
# [3] cer 0 wer 0 gold እንደት ነህ:7 hyp እንደት ነህ:7 SUCCESS
# [4] cer 0 wer 0 gold ኧረ:2 hyp ኧረ:2 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ሀያ:2 hyp ሀያ:2 SUCCESS
# [1] cer 3 wer 2 gold እንደት ነው ታዲያ:11 hyp እንደት ነሽ ነዲ:10
# [2] cer 1 wer 1 gold ምን የሚሰፋው:8 hyp ምን የሚሰውው:8
# [3] cer 0 wer 0 gold አቤት አቤት:7 hyp አቤት አቤት:7 SUCCESS
# [4] cer 0 wer 0 gold እህትሽ:4 hyp እህትሽ:4 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 2 wer 1 gold ስማ ኧረ ሳልጠይቅህ እስኪ:16 hyp ስማ ኧረ ሳምጠይህህ እስኪ:16
# [1] cer 0 wer 0 gold ቆንጆ ነው እየተማርክ ነው:16 hyp ቆንጆ ነው እየተማርክ ነው:16 SUCCESS
# [2] cer 0 wer 0 gold የእራስን ቡድን ሲክድ:13 hyp የእራስን ቡድን ሲክድ:13 SUCCESS
# [3] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [4] cer 0 wer 0 gold ወስጄ:3 hyp ወስጄ:3 SUCCESS
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 3 wer 3 gold እንደ አንተ እስካሁን:13 hyp እንት አንተ እስ ሁ:12
# [1] cer 2 wer 1 gold እንደው የወለደ ከብት የለም:17 hyp እንደው የወለደ የምት የለም:17
# [2] cer 0 wer 2 gold ሁሉም ደህና ናቸው እ:13 hyp ሁሉም ደህና ናቸውእ:12
# [3] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [4] cer 1 wer 1 gold አዎ ደውል በቃ:9 hyp አዎ አውል በቃ :10
# [5] cer 0 wer 0 gold ስማ ኳስ:5 hyp ስማ ኳስ:5 SUCCESS
# [6] cer 0 wer 0 gold ዶሮ አይበቃም:8 hyp ዶሮ አይበቃም:8 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 1 wer 1 gold እልሀለሁ እልሀለሁ እልሀለሁ:17 hyp እልሀለሁ እልሀኝሁ እልሀለሁ:17
# [1] cer 1 wer 1 gold አይ ሆላንዶች ማን ነበረ:15 hyp አይ ሆላንዶች ማን ማበረ :16
# [2] cer 0 wer 0 gold ሰው አግኝቼልሽ ነበረ:13 hyp ሰው አግኝቼልሽ ነበረ:13 SUCCESS
# [3] cer 0 wer 0 gold ሰለቼሽ:4 hyp ሰለቼሽ:4 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 3 wer 3 gold አላየሁትም አዲስ ነው:13 hyp አላየሁትምምአዲወ ነች:13
# [1] cer 0 wer 0 gold አዎ አሁን መቷል:10 hyp አዎ አሁን መቷል:10 SUCCESS
# [2] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [3] cer 0 wer 0 gold አይ አልራበንም:9 hyp አይ አልራበንም:9 SUCCESS
# [4] cer 0 wer 0 gold እምን:3 hyp እምን:3 SUCCESS
# [5] cer 0 wer 0 gold ደህና ነው:6 hyp ደህና ነው:6 SUCCESS
# [6] cer 0 wer 0 gold የት ሂዳ ነው:8 hyp የት ሂዳ ነው:8 SUCCESS
# [7] cer 0 wer 0 gold ሰራሽ:3 hyp ሰራሽ:3 SUCCESS
# [0] cer 1 wer 1 gold በደንብ እየሰራችሁ ነው:14 hyp በደንብ እየሰራች  ነው:14
# [1] cer 1 wer 1 gold አቤት አዎ ከዶርም ውጭ:14 hyp አቤት አዎ ከዶምም ውጭ:14
# [2] cer 1 wer 1 gold አቤት ሚጣስ አደገች:12 hyp አቤት ሚጣስ አብገች:12
# [3] cer 0 wer 0 gold ዳሽን ዘጠነኛ ነው:11 hyp ዳሽን ዘጠነኛ ነው:11 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ እንደት ነሽ:10 hyp ሄሎ እንደት ነሽ:10 SUCCESS
# [5] cer 2 wer 1 gold አ ምን አለ አ :10 hyp አ ምን አ   :9
# [6] cer 0 wer 0 gold ሄዶ ነበር አዎ:9 hyp ሄዶ ነበር አዎ:9 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 3 wer 2 gold አዎ እንደዚያ ይሻላል:13 hyp አዎ አንደዚያ ናሻላህ:13
# [1] cer 2 wer 1 gold አዎ ማማሳ ማማ ትደውያለሽ:16 hyp አዎ ማማሳ ማማ ትደለለሽ:15
# [2] cer 0 wer 0 gold አትመጣም አለችኝ:10 hyp አትመጣም አለችኝ:10 SUCCESS
# [3] cer 0 wer 0 gold ለ ኦኬ:4 hyp ለ ኦኬ:4 SUCCESS
# [4] cer 0 wer 0 gold እ አዎ:4 hyp እ አዎ:4 SUCCESS
# [5] cer 1 wer 1 gold አሁን አዲሱ ስልክህስ:13 hyp አሁን አዲሱ ስልክህስክ:14
# [6] cer 0 wer 0 gold ከአንተ የሚጠበቅ:10 hyp ከአንተ የሚጠበቅ:10 SUCCESS
# [7] cer 0 wer 0 gold እሺ አባቴ:6 hyp እሺ አባቴ:6 SUCCESS
# [0] cer 0 wer 0 gold በአሁን ሰዐት:8 hyp በአሁን ሰዐት:8 SUCCESS
# [1] cer 0 wer 0 gold ምን ምን:5 hyp ምን ምን:5 SUCCESS
# [2] cer 1 wer 1 gold እንደት ነው አ:9 hyp ኦንደት ነው አ:9
# [3] cer 0 wer 0 gold የእውነት:5 hyp የእውነት:5 SUCCESS
# [4] cer 1 wer 1 gold አንተ አታየውም:9 hyp አንተ አታየውምም:10
# [5] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [0] cer 0 wer 0 gold እ ሰኔ ስድስት:9 hyp እ ሰኔ ስድስት:9 SUCCESS
# [1] cer 4 wer 2 gold አንድ ሁለት ቀን አሳርፈዋችኋላ:19 hyp አንድ ሁለሁ ቀን አሳርፈችችኋርች:20
# [2] cer 0 wer 0 gold ግን ደህና ነሽ አንቺ:13 hyp ግን ደህና ነሽ አንቺ:13 SUCCESS
# [3] cer 0 wer 0 gold አንቺ ደህና ነሽ:10 hyp አንቺ ደህና ነሽ:10 SUCCESS
# [4] cer 0 wer 0 gold አይሰማሽም:6 hyp አይሰማሽም:6 SUCCESS
# [5] cer 0 wer 0 gold በቃ:2 hyp በቃ:2 SUCCESS
# [6] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold በጣም ትልቅ እንጂ:11 hyp በጣም ትልቅ እንጂ:11 SUCCESS
# [1] cer 4 wer 1 gold እንደት አይመለከትህም እንደ:17 hyp እንደት የይመለከሁ   እንደ:17
# [2] cer 2 wer 2 gold ጤናቸውስ አሁን ደህና ነው:16 hyp ጤናቸውስ አሁን ነህና ነውና:17
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 4 wer 3 gold እንደምን ዋልክ እንደምን ዋልክ:19 hyp እንደምን ዋልክዋደምዋልክን:16
# [5] cer 0 wer 0 gold እሱማ አይቀርም:9 hyp እሱማ አይቀርም:9 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ ዮሐንስ:7 hyp ሄሎ ዮሐንስ:7 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold እንደት ነሽ ሰላም ነው:14 hyp እንደት ነሽ ሰላም ነው:14 SUCCESS
# [1] cer 6 wer 4 gold ታክሲ በድብድብ አይደል የያዝኩት:20 hyp ኧክሲ በድብብብ አንደልየከከት:18
# [2] cer 0 wer 0 gold በጭንቅላት ነው:9 hyp በጭንቅላት ነው :10
# [3] cer 0 wer 0 gold መምጣቱማ አይቀርም:11 hyp መምጣቱማ አይቀርም:11 SUCCESS
# [4] cer 1 wer 1 gold ግራውን ግራውን:9 hyp ግራውን ግራው:8
# [5] cer 0 wer 0 gold ሳይ አናገርኳቸው:10 hyp ሳይ አናገርኳቸው:10 SUCCESS
# [6] cer 0 wer 0 gold እናትዬስ:5 hyp እናትዬስ:5 SUCCESS
# [7] cer 2 wer 2 gold ኤድዬ እንደት ነሽ:11 hyp ኤድዬ ስን ት ነሽ:11
# [0] cer 2 wer 1 gold መቼ ነበር የተወዳደርሽው:15 hyp መቼ ነበር የተወዳደደሽውው:16
# [1] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [2] cer 0 wer 0 gold ምን ከእዛ ገዝታችሁ ነው:15 hyp ምን ከእዛ ገዝታችሁ ነው:15 SUCCESS
# [3] cer 0 wer 0 gold ችግር የለም:7 hyp ችግር የለም:7 SUCCESS
# [4] cer 1 wer 1 gold ምንም የወጣ ነገር የለም:15 hyp ምንም የወጣ የገር የለም:15
# [5] cer 0 wer 0 gold አልመጣችም:6 hyp አልመጣችም:6 SUCCESS
# [6] cer 0 wer 0 gold ኦኬ:2 hyp ኦኬ:2 SUCCESS
# [7] cer 0 wer 0 gold ጠፋህ:3 hyp ጠፋህ:3 SUCCESS
# [0] cer 3 wer 1 gold ዛሬ ዛሬ የለም ትምህርት:15 hyp ዛሬ ዛሬ የለም ትምምርምር:16
# [1] cer 3 wer 2 gold አይ አሁን በቅርብ አልሄድም:17 hyp አይ አሁን አሰርብ አድሄድም:17
# [2] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [3] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [4] cer 0 wer 0 gold ምን አዲስ ማለት:10 hyp ምን አዲስ ማለት:10 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 3 wer 2 gold አዎ ይጠያየቃሉ ሰላም ናቸው:17 hyp አዎ ይጠላየቃሉ ናላየ ናቸው:17
# [1] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [2] cer 1 wer 1 gold አዎ እንደዚያ አለች እኮ:15 hyp አዎ እንደዚያ አለች አኮ:15
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 0 wer 0 gold የእሱን:4 hyp የእሱን:4 SUCCESS
# [5] cer 0 wer 0 gold አይደል:4 hyp አይደል:4 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold አንቺ አቢ እየሠራ ነው:14 hyp አንቺ አቢ እየሠራ ነው:14 SUCCESS
# [1] cer 1 wer 1 gold ወለደች እንደ:8 hyp ወለደች ወንደ:8
# [2] cer 1 wer 1 gold እንደዚያ ነው ብለሽ ነው:15 hyp እንደዚያ ነው ብለም ነው:15
# [3] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [4] cer 0 wer 0 gold እሺ አዎ:5 hyp እሺ አዎ:5 SUCCESS
# [5] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold ያዝ:2 hyp ያዝ:2 SUCCESS
# [0] cer 2 wer 1 gold አለ አገሩ ገብቶ ቀረ:13 hyp አለ አገሩ ቀብ  ቀረ:13
# [1] cer 0 wer 0 gold ምን ኧረ እባክሽ:10 hyp ምን ኧረ እባክሽ:10 SUCCESS
# [2] cer 0 wer 0 gold ወይ አሰበ ዛሬ:9 hyp ወይ አሰበ ዛሬ:9 SUCCESS
# [3] cer 0 wer 0 gold ፈተና አዎ:6 hyp ፈተና አዎ:6 SUCCESS
# [4] cer 0 wer 0 gold እንኳን ደህና ሆነ:11 hyp እንኳን ደህና ሆነ:11 SUCCESS
# [5] cer 0 wer 0 gold እመጣለሁ እመጣለሁ:11 hyp እመጣለሁ እመጣለሁ:11 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 6 wer 3 gold አዎ መጫወት እንኳን እንጫወታለን:20 hyp አዎ ንታወወ ሆንኳን እንጫታታንን:20
# [1] cer 0 wer 0 gold እ ምን ሀበሻ:8 hyp እ ምን ሀበሻ:8 SUCCESS
# [2] cer 0 wer 0 gold ይሠማሻል:5 hyp ይሠማሻል:5 SUCCESS
# [3] cer 0 wer 0 gold አይ ተዘጋጅተዋል:10 hyp አይ ተዘጋጅተዋል:10 SUCCESS
# [4] cer 0 wer 0 gold የቅርብ ሰው:7 hyp የቅርብ ሰው:7 SUCCESS
# [5] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# ...
# [4] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [5] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 2 gold ምን ታደርገዋለህ ያው አለቀሱብን:20 hyp ምን ታደርገዋለህ ያውብአለቀሱብንብ:21
# [1] cer 3 wer 2 gold አልጠፋም እኔ አንተ አለሁ:16 hyp አልጠፋም እኔ አለ  አንሁ:16
# [2] cer 8 wer 3 gold ትራንስፈር ታደርገዋለህ ወይ ያንን:21 hyp ትራንስፈር ወለለንህለህ ያይ ያ :20
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 2 gold እ ትናንትና ይሰማኛል ይሰማኛል:19 hyp እሺትናንትና ይሰማኛል ይሰማኛል:19
# [1] cer 1 wer 1 gold እንደቸርነቱ ለእኛማ ቆንጆ ነው:19 hyp እንደቸርነቱ ለኛኛማ ቆንጆ ነው:19
# [2] cer 0 wer 0 gold ሥራ ም :5 hyp ሥራ ም :5 SUCCESS
# [3] cer 1 wer 1 gold አልተመቻቸልኝም:9 hyp አልተመቻቸልኝምም:10
# [4] cer 0 wer 0 gold እውነት:4 hyp እውነት:4 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ እ እ:5 hyp እ እ እ:5 SUCCESS
# [7] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [0] cer 0 wer 0 gold ኦኬ ኦኬ:5 hyp ኦኬ ኦኬ:5 SUCCESS
# [1] cer 0 wer 0 gold አዎ ሁሉም ሰላም ናቸው:14 hyp አዎ ሁሉም ሰላም ናቸው:14 SUCCESS
# [2] cer 1 wer 2 gold ምን ታደርገዋለህ:10 hyp ምን ታደ ገዋለህ:10
# [3] cer 0 wer 0 gold ኧረ እቆያለሁ:8 hyp ኧረ እቆያለሁ:8 SUCCESS
# [4] cer 0 wer 0 gold እረሳ:3 hyp እረሳ:3 SUCCESS
# [5] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold አ:1 hyp አ:1 SUCCESS
# [0] cer 0 wer 0 gold አዎ ሀንዬ አይበቃም:12 hyp አዎ ሀንዬ አይበቃም:12 SUCCESS
# [1] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [2] cer 0 wer 0 gold እንትን ከእዚህ:9 hyp እንትን ከእዚህ:9 SUCCESS
# [3] cer 0 wer 0 gold አንተ አንተ:7 hyp አንተ አንተ:7 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold እሱ ጋር:5 hyp እሱ ጋር:5 SUCCESS
# [1] cer 0 wer 0 gold ደህና ነሽ እንደት ነው:14 hyp ደህና ነሽ እንደት ነው:14 SUCCESS
# [2] cer 3 wer 2 gold እሺ ይመጣልሀል ችግር የለውም:18 hyp እሺ ይመጣልልል ችግር የርውምም:19
# [3] cer 3 wer 3 gold አዎ ስንት ዐመት:10 hyp አይ ስን  ዐመለ:10
# [4] cer 0 wer 0 gold ቤተሰብ ሁሉ ሰላም ነው:14 hyp ቤተሰብ ሁሉ ሰላም ነው:14 SUCCESS
# [5] cer 0 wer 0 gold የገባች ይመስለኛል:11 hyp የገባች ይመስለኛል:11 SUCCESS
# [6] cer 0 wer 0 gold ሰላሳ ዘጠኝ ይሁን:11 hyp ሰላሳ ዘጠኝ ይሁን:11 SUCCESS
# [7] cer 0 wer 0 gold ምን:2 hyp ምን:2 SUCCESS
# [0] cer 1 wer 1 gold ሄሎ ሰላም ነህ:9 hyp ሄሎ ሰላም ነህነ:10
# [1] cer 1 wer 2 gold እና ምን ባደርግ ይሻለኛል:16 hyp እና ምን ባደ ግ ይሻለኛል:16
# [2] cer 1 wer 2 gold ፕሮግራሚንግ አሳይንመንት ሰራህ:19 hyp ፕሮግራሚንግ አሳይንመንመሰራህ:18
# [3] cer 1 wer 1 gold የት ነው የምታየው:11 hyp የት ነው የምየው:10
# [4] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [5] cer 0 wer 0 gold ሌላስ:3 hyp ሌላስ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold አዎ ይዘሀት ና እሷንም:14 hyp አዎ ይዘሀት ና እሷንም:14 SUCCESS
# [1] cer 4 wer 2 gold ኧረ እንዳትቀየሚ የለብሽም:16 hyp ኧረ አዳዳትቀሚሚ የለብሽምም:17
# [2] cer 1 wer 3 gold ኦኬ ደህና ነህ በተረፈ:14 hyp ኦኬ ደህ  ነህበተረፈ:13
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 0 wer 0 gold አዎ በቃ:5 hyp አዎ በቃ:5 SUCCESS
# [5] cer 1 wer 1 gold እ እንደት ነው ታድያ:13 hyp እ እንደት ይው ታድያ:13
# [6] cer 0 wer 0 gold ቀለም ቀቢው:7 hyp ቀለም ቀቢው:7 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እ:1 hyp እ :2
# [1] cer 0 wer 0 gold ም :2 hyp ም :2 SUCCESS
# [2] cer 0 wer 0 gold አይዞሽ እቴትዬ:9 hyp አይዞሽ እቴትዬ:9 SUCCESS
# [3] cer 1 wer 1 gold አልደወለልኝም:8 hyp አልደወለልኝ:7
# [4] cer 1 wer 1 gold እንደት ነው ደህና ነው:14 hyp እንደት ነው ደህና ወው:14
# [5] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold አዎ አዎ እንደ በጣም:13 hyp አዎ አዎ ምንደ በጣም:13
# [1] cer 12 wer 4 gold መስመር ሠራተኞችም ብትለው መሀንዲሶቹም:24 hyp ምስመር ታራትኞች  ብሀ ምይሀዲዲምህነ:23
# [2] cer 1 wer 1 gold ዛሬ ማማሟቂያ ብቻ ነው:14 hyp ዛሬ ማማሟቂያ ነቻ ነው:14
# [3] cer 0 wer 0 gold ሁሉንም ሰው አዎ:10 hyp ሁሉንም ሰው አዎ:10 SUCCESS
# [4] cer 1 wer 1 gold መሰረትስ ገብታለች ሥራ:14 hyp መሰረትስ ገብለለች ሥራ:14
# [5] cer 0 wer 0 gold በተረፈ:4 hyp በተረፈ:4 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 5 wer 4 gold ስለዚህ እን  እንዳትጨናነቂ:17 hyp በለዚህ እን  እን ት ነቂነ:17
# [1] cer 0 wer 0 gold አዎ አዎ:5 hyp አዎ አዎ:5 SUCCESS
# [2] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [3] cer 0 wer 0 gold በቃ በዛኝ :7 hyp በቃ በዛኝ :7 SUCCESS
# [4] cer 0 wer 0 gold አልፈቀዱም:6 hyp አልፈቀዱም:6 SUCCESS
# [5] cer 2 wer 1 gold አሁን ልትመጣ ነው:11 hyp አሁን ልትመጣ አውአ:12
# [6] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 0 wer 0 gold አቤት አቤት:7 hyp አቤት አቤት:7 SUCCESS
# [1] cer 3 wer 2 gold በግማ ታረደ ይበቃሀል:13 hyp ምግማ ታረደ ይቃቃሀልሀ:14
# [2] cer 0 wer 0 gold ስለምን ላውራህ እባክህ:14 hyp ስለምን ላውራህ እባክህ:14 SUCCESS
# [3] cer 0 wer 0 gold የልጆቹስ:5 hyp የልጆቹስ:5 SUCCESS
# [4] cer 0 wer 0 gold እቴ ባልሽ ደህና ነው:13 hyp እቴ ባልሽ ደህና ነው:13 SUCCESS
# [5] cer 0 wer 0 gold አዎ የወጣው እኮ:10 hyp አዎ የወጣው እኮ:10 SUCCESS
# [6] cer 1 wer 1 gold ኧረ አለሁ:6 hyp ኧረ አለ :6
# [7] cer 0 wer 0 gold የጦሲኝ:4 hyp የጦሲኝ:4 SUCCESS
# [0] cer 4 wer 3 gold በጣም እርካሽ ነው ጂንሱ:15 hyp በጣም እር ሽ ነው አንናን:16
# [1] cer 0 wer 0 gold ከማን ጋር:6 hyp ከማን ጋር:6 SUCCESS
# [2] cer 1 wer 1 gold አዎ እኔ የምልሽ:10 hyp ኧዎ እኔ የምልሽ:10
# [3] cer 0 wer 0 gold አዎ ደህና መጣሁ:10 hyp አዎ ደህና መጣሁ:10 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 4 wer 4 gold ምን እያደረግህ ነው አሁን:16 hyp ምን ብያ ረግህ አው አለን:16
# [6] cer 0 wer 0 gold በእውነት:5 hyp በእውነት:5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold እሺ ሰላም በይልኝ:11 hyp እሺ ሰላም በይልኝ:11 SUCCESS
# [1] cer 10 wer 5 gold መቼም ደውሎልህም አያውቅም አልተገናኛችሁም:26 hyp መቼ  ደው ል ም አልተቅምቅልተገና:21
# [2] cer 0 wer 0 gold እንደት ነሽ አንቺ:11 hyp እንደት ነሽ አንቺ:11 SUCCESS
# [3] cer 0 wer 0 gold ኧረ ሀቢታትስ:8 hyp ኧረ ሀቢታትስ:8 SUCCESS
# [4] cer 0 wer 0 gold ወደ እናንተ:7 hyp ወደ እናንተ:7 SUCCESS
# [5] cer 0 wer 0 gold አዎ አይ:5 hyp አዎ አይ:5 SUCCESS
# [6] cer 0 wer 0 gold አልተገናኝ :7 hyp አልተገናኝ :7 SUCCESS
# [7] cer 0 wer 0 gold ምን አልከኝ:7 hyp ምን አልከኝ:7 SUCCESS
# [0] cer 2 wer 2 gold ብዙ ትቆያላችሁ ከእሷ ጋር:16 hyp ብዙ ሸቆያላችሁ ከእሷ ከር:16
# [1] cer 5 wer 4 gold የተከለከሉ አማርኛዎችን ነው የምጠቀመው:24 hyp የተከለከሉ አማርኛዎ   የው የም ቀመቀ :25
# [2] cer 0 wer 0 gold በስመ አብ:6 hyp በስመ አብ:6 SUCCESS
# [3] cer 0 wer 0 gold ደህና ናት ደህና ናት:13 hyp ደህና ናት ደህና ናት:13 SUCCESS
# [4] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [5] cer 0 wer 0 gold አቤት:3 hyp አቤት:3 SUCCESS
# [6] cer 0 wer 0 gold ወጣ:2 hyp ወጣ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 2 gold መቷል እንደ የውስጥ እ:14 hyp መቷል እንደ የውስጥስእ:14
# [1] cer 2 wer 2 gold አዎ ሥራ እንደት ነው:13 hyp አዎ ሥራ እንዳት ነውአ:14
# [2] cer 0 wer 0 gold እንደት ነው:7 hyp እንደት ነው:7 SUCCESS
# [3] cer 0 wer 0 gold አዎ አሪፍ ነው:9 hyp አዎ አሪፍ ነው:9 SUCCESS
# [4] cer 0 wer 0 gold ግልባጩ:4 hyp ግልባጩ:4 SUCCESS
# [5] cer 0 wer 0 gold ኧረ በስመ አብ:9 hyp ኧረ በስመ አብ:9 SUCCESS
# [6] cer 1 wer 1 gold አልጋ ላይ ተኝተህ:11 hyp አልጋ ላይ አኝተህ :12
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold አዎ ሰላም ብላሀለች እኮ:15 hyp አዎ ሰላም ብላሀለች እኮ:15 SUCCESS
# [1] cer 0 wer 0 gold ሰላም ነኝ እ:8 hyp ሰላም ነኝ እ:8 SUCCESS
# [2] cer 2 wer 2 gold እ እና አልደወሉም እስካሁን:17 hyp እ እዛ አልደወሉም እስካሁንን:18
# [3] cer 1 wer 1 gold ገና ዛሬ አይደለ:10 hyp ገና ዛሬ ይይደለ:10
# [4] cer 0 wer 0 gold ሰላም መጡ:6 hyp ሰላም መጡ:6 SUCCESS
# [5] cer 0 wer 0 gold አይደለ:4 hyp አይደለ:4 SUCCESS
# [6] cer 0 wer 0 gold ሰላም ነው:6 hyp ሰላም ነው:6 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 1 wer 1 gold እ ምን አለሽ:8 hyp እ ም  አለሽ:8
# [1] cer 4 wer 2 gold ያልተማረ ሰው ወየውለት:14 hyp ሱልተማረ ሰው ወውውሁ:13
# [2] cer 1 wer 2 gold እና ማለት አንተ ስማ:13 hyp እና ማለትኝአንተ ስማ:13
# [3] cer 0 wer 0 gold አዝመራው እንደት ነው:13 hyp አዝመራው እንደት ነው:13 SUCCESS
# [4] cer 0 wer 0 gold አሀ:2 hyp አሀ:2 SUCCESS
# [5] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [0] cer 3 wer 1 gold አይ እናቷስ ደህና ነች:14 hyp አይ እየ   ደህና ነች:14
# [1] cer 1 wer 2 gold አሪፍ ነው አንቺስ:11 hyp አሪፍ ነውአንቺ:9
# [2] cer 4 wer 3 gold አይሰማም አይስማም በደንብ ንገረኝ:21 hyp አይሰማም አይስምም ንደንብ ንንንኝ:21
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 1 wer 1 gold አ  ሌላ ሲም:8 hyp አይ ሌላ ሲም:8
# [5] cer 1 wer 1 gold አዎ ይሰማል ይሰማል:12 hyp አዎ አሰማል ይሰማል:12
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 1 gold አ  አሁን ዝግጅቱስ:12 hyp አ  አሁን ዝግጅስስስ:13
# [1] cer 0 wer 0 gold ከተነጋገርን:7 hyp ከተነጋገርን:7 SUCCESS
# [2] cer 0 wer 0 gold ደህና ናቸው:7 hyp ደህና ናቸው:7 SUCCESS
# [3] cer 1 wer 1 gold ምን ይሰጣሉ ብለሽ ነው:14 hyp ምን ይሰጣ  ብለሽ ነው:14
# [4] cer 0 wer 0 gold ፊልም ቤት:6 hyp ፊልም ቤት:6 SUCCESS
# [5] cer 0 wer 0 gold የአበባውን:6 hyp የአበባውን:6 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold የምንመኘው:6 hyp የምንመኘው:6 SUCCESS
# [1] cer 0 wer 0 gold አንድ ቡድን ወረደ ማን:14 hyp አንድ ቡድን ወረደ ማን:14 SUCCESS
# [2] cer 0 wer 0 gold እሺ እሺ እሺ:8 hyp እሺ እሺ እሺ:8 SUCCESS
# [3] cer 1 wer 1 gold እሺ ሰጠሻቸው:8 hyp እሺ ሰጠጠቸው:8
# [4] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [0] cer 0 wer 0 gold ለሶስት ወር ነው መተው:14 hyp ለሶስት ወር ነው መተው:14 SUCCESS
# [1] cer 4 wer 2 gold ቁም ነገር ነው አትቀልድ:15 hyp ቁም ነገ  ነው የትቀናድድ:16
# [2] cer 0 wer 0 gold ዌይተር ላይ ቢሰራም እ:14 hyp ዌይተር ላይ ቢሰራም እ:14 SUCCESS
# [3] cer 1 wer 3 gold የስካሁኑ እንደዚያ ነው እ:16 hyp የስካሁኑ እንዚያ ነውእ:14
# [4] cer 0 wer 0 gold እንደ በጣም:7 hyp እንደ በጣም:7 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold አዎ እሺ:5 hyp አዎ እሺ:5 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ማለት እፈልጋለሁ እሺ:13 hyp ማለት እፈልጋለሁ እሺ:13 SUCCESS
# [1] cer 0 wer 0 gold ሄሎ አዎ:5 hyp ሄሎ አዎ:5 SUCCESS
# [2] cer 0 wer 0 gold ስንት ነው ደግሞ እሱ:13 hyp ስንት ነው ደግሞ እሱ:13 SUCCESS
# [3] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [4] cer 0 wer 0 gold አይ አሪፍ ነው በቃ:12 hyp አይ አሪፍ ነው በቃ:12 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold እናንተ:4 hyp እናንተ:4 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 4 wer 3 gold በጳጳስ ጳጳሱ በኩል:12 hyp በጳጳ  ጳጳን በላ:11
# [1] cer 0 wer 0 gold እ ቆይ ልጻፈው:9 hyp እ ቆይ ልጻፈው:9 SUCCESS
# [2] cer 3 wer 3 gold ቃሊቲ አይደለም ጉርድ ሾላ:16 hyp ቃሊቲ አይባምም ጉርድድሾላ:16
# [3] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [4] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [5] cer 0 wer 0 gold ቤተሰብ:4 hyp ቤተሰብ:4 SUCCESS
# [6] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [7] cer 0 wer 0 gold እ እ:3 hyp እ እ:3 SUCCESS
# [0] cer 2 wer 2 gold እ እኔ ምንም አልደወልክልኝም:18 hyp እ  ኔ ምንም አልደወልክልኝምም:19
# [1] cer 2 wer 2 gold ትንሽማ ትንሽማ ያስፈልጋል:16 hyp እንሽማ ትንሽማ ያስፈልንል:16
# [2] cer 0 wer 0 gold ቡቃያውስ እንደት ነው:13 hyp ቡቃያውስ እንደት ነው:13 SUCCESS
# [3] cer 0 wer 0 gold እ የት ነው ያለኸው:12 hyp እ የት ነው ያለኸው:12 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [5] cer 0 wer 0 gold በጣም በጣም በጣም:11 hyp በጣም በጣም በጣም:11 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold ቀረፃ አለው:7 hyp ቀረፃ አለው:7 SUCCESS
# [0] cer 5 wer 4 gold የምትይውም አይሰማም በደንብ ሄሎ:20 hyp የምትይው  የይሰማም በደም  በሎ:20
# [1] cer 0 wer 0 gold ኦ አምቦ:5 hyp ኦ አምቦ:5 SUCCESS
# [2] cer 0 wer 0 gold አሁን አሁን የካ ፓርክ:14 hyp አሁን አሁን የካ ፓርክ:14 SUCCESS
# [3] cer 1 wer 1 gold እሺ የሚላስ ሰላም ነው:14 hyp እሺ የሚላስ ፍላም ነው:14
# [4] cer 0 wer 0 gold አሪፍ ነው:6 hyp አሪፍ ነው:6 SUCCESS
# [5] cer 0 wer 0 gold አለ አይደል:7 hyp አለ አይደል:7 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [0] cer 1 wer 1 gold ቅቤሳ ቅቤ ስንት ገባ:13 hyp ቅቤሳ ቅቤ ስን  ገባ:13
# [1] cer 0 wer 0 gold ሰሞኑን እንደዚህ ነው:13 hyp ሰሞኑን እንደዚህ ነው:13 SUCCESS
# [2] cer 2 wer 3 gold አዎ እንደሱ አለኝ እንግዲህ:17 hyp አዎ እን ሱ አለኝንግዲህ:15
# [3] cer 0 wer 0 gold ኧረ ይሻላል:7 hyp ኧረ ይሻላል:7 SUCCESS
# [4] cer 0 wer 0 gold ሄሎ ሄሎ:5 hyp ሄሎ ሄሎ:5 SUCCESS
# [5] cer 0 wer 0 gold መቼ:2 hyp መቼ:2 SUCCESS
# [6] cer 0 wer 0 gold ደህና ነች:6 hyp ደህና ነች:6 SUCCESS
# [7] cer 0 wer 0 gold ኦኬ:2 hyp ኦኬ:2 SUCCESS
# [0] cer 0 wer 0 gold እሺ እሺ በቃ እናት:12 hyp እሺ እሺ በቃ እናት:12 SUCCESS
# [1] cer 5 wer 3 gold ቤተ ክርስትያኑ የሚሄድ አይደለም:20 hyp ቤተ ክር ትያያስየሚሄይንአይደለም:20
# [2] cer 0 wer 0 gold የመጨረሻ:5 hyp የመጨረሻ:5 SUCCESS
# [3] cer 1 wer 1 gold አትይኝም:5 hyp አሁይኝም:5
# [4] cer 1 wer 1 gold ኦኬ እቤት ነሽ:9 hyp እኬ እቤት ነሽ:9
# [5] cer 0 wer 0 gold እ እ እ:5 hyp እ እ እ:5 SUCCESS
# [6] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [7] cer 0 wer 0 gold ምን:2 hyp ምን:2 SUCCESS
# [0] cer 0 wer 0 gold እ እኔ ይስማ :9 hyp እ እኔ ይስማ :9 SUCCESS
# [1] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [2] cer 2 wer 2 gold እ የውሸት ቀን:9 hyp ች የውሸ  ቀን:9
# [3] cer 0 wer 0 gold እሺ ሰላም ነው በተረፈ:14 hyp እሺ ሰላም ነው በተረፈ:14 SUCCESS
# [4] cer 0 wer 0 gold ኦኬ እሺ እሺ:8 hyp ኦኬ እሺ እሺ:8 SUCCESS
# [5] cer 0 wer 0 gold አትታየኝም:6 hyp አትታየኝም:6 SUCCESS
# [6] cer 0 wer 0 gold እስኪ:3 hyp እስኪ:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 2 wer 2 gold አረ ኧረ እኔ አልሞከርኩም:16 hyp አረ ኧረ አኔ አልሞኩርኩም:16
# [1] cer 1 wer 1 gold ዝግ ነበር አዎ:9 hyp ዝግ ነበር የዎ:9
# [2] cer 1 wer 1 gold አልተመቸህም:7 hyp አልመመቸህም:7
# [3] cer 1 wer 1 gold አይሻልም:5 hyp እይሻልም:5
# [4] cer 0 wer 0 gold ሄሎ ሄሎ:5 hyp ሄሎ ሄሎ:5 SUCCESS
# [5] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold ቀን:2 hyp ቀን:2 SUCCESS
# [0] cer 1 wer 2 gold ተመልካቾቹ ብዙ ናቸው:13 hyp ተመልካቾቹ ብዙ ና ው:13
# [1] cer 1 wer 1 gold በነሐሴ አስራ መነኩሴ ይባላል:18 hyp በነሐሴ አስራ ይነኩሴ ይባላል:18
# [2] cer 2 wer 1 gold አዎ አዚዛ ደውላልኝ ነበረ:16 hyp አዎ አዚዛ ደውላልኝ አውረ:16
# [3] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold አለን:3 hyp አለን:3 SUCCESS
# [6] cer 0 wer 0 gold ፈይሰል:4 hyp ፈይሰል:4 SUCCESS
# [7] cer 0 wer 0 gold አለሁ:3 hyp አለሁ:3 SUCCESS
# [0] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [1] cer 2 wer 2 gold ቢጠቀም ጥሩ ነው አይደለ:15 hyp ቢጠቀም ጥሩ አው አይደለሽ:16
# [2] cer 0 wer 0 gold ማለዱ ጋር አዎ:9 hyp ማለዱ ጋር አዎ:9 SUCCESS
# [3] cer 0 wer 0 gold ደህና ናት:6 hyp ደህና ናት:6 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [6] cer 0 wer 0 gold ማን ጋር:5 hyp ማን ጋር:5 SUCCESS
# [7] cer 0 wer 0 gold እሺ:2 hyp እሺ:2 SUCCESS
# [0] cer 4 wer 4 gold እስካሁን የሚያድርለት ሰው አላገኘም:22 hyp እንካሁን የሚያድ ንሁ ሰውአላገኘም:21
# [1] cer 0 wer 0 gold አቤት አቤት:7 hyp አቤት አቤት:7 SUCCESS
# [2] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [3] cer 0 wer 0 gold ደህና ናት:6 hyp ደህና ናት:6 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold ሥራ:2 hyp ሥራ:2 SUCCESS
# [6] cer 0 wer 0 gold ምነው:3 hyp ምነው:3 SUCCESS
# [7] cer 0 wer 0 gold በስንት:4 hyp በስንት:4 SUCCESS
# [0] cer 3 wer 2 gold አዎ አትጥፉ ደውሉልን:13 hyp አዎ አትጥ  ደውል:11
# [1] cer 0 wer 0 gold ምናምን አሉት ከእዛ:12 hyp ምናምን አሉት ከእዛ:12 SUCCESS
# [2] cer 1 wer 1 gold በድምጽ ብልጫ ይሁን:12 hyp በድምጽ ብል  ይሁን:12
# [3] cer 0 wer 0 gold አንተ እንቢ አልክ ደግሞ:15 hyp አንተ እንቢ አልክ ደግሞ:15 SUCCESS
# [4] cer 0 wer 0 gold አይ ዋናው ማሰቧ ነው:13 hyp አይ ዋናው ማሰቧ ነው:13 SUCCESS
# [5] cer 0 wer 0 gold ኧረ በለው:6 hyp ኧረ በለው:6 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ትናንት ማለት ነው:11 hyp ትናንት ማለት ነው:11 SUCCESS
# [1] cer 6 wer 4 gold ከስልጠና ልጆች ሄደዋል በቃ:17 hyp በስልጠና ልጆ  ትደኝሽ በኝ:17
# [2] cer 3 wer 2 gold ችግር የለም ደግፈን እናበላሀለን:20 hyp ችግር የለም ደግፈ  እናበላሀበህ:20
# [3] cer 0 wer 0 gold አ:1 hyp አ:1 SUCCESS
# [4] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [5] cer 0 wer 0 gold ኧረ:2 hyp ኧረ:2 SUCCESS
# [6] cer 0 wer 0 gold ወዴት:3 hyp ወዴት:3 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold ኤሌክትሪካል ፐርፌክት:13 hyp ኤሌክትሪካል ፐርፌትት:13
# [1] cer 0 wer 0 gold ተሽሎታል አይሰማም እንደ:15 hyp ተሽሎታል አይሰማም እንደ:15 SUCCESS
# [2] cer 2 wer 2 gold ኦኬ ጥሩ ያስብለታል:12 hyp ኦኬ ጥሩ ያስብለ ለ :13
# [3] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [4] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [5] cer 0 wer 0 gold ችግር የለም:7 hyp ችግር የለም:7 SUCCESS
# [6] cer 0 wer 0 gold ሄሎ:2 hyp ሄሎ:2 SUCCESS
# [7] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS
# [0] cer 0 wer 0 gold እ አዎ:4 hyp እ አዎ:4 SUCCESS
# [1] cer 0 wer 0 gold ኧረ አላለቀም ቀስ ይላል:15 hyp ኧረ አላለቀም ቀስ ይላል:15 SUCCESS
# [2] cer 1 wer 1 gold እና እኔንም ከሰው:11 hyp እና እኔትም ከሰው:11
# [3] cer 2 wer 1 gold በቃ ቸግሮኝ:7 hyp በቃ አግሮን:7
# [4] cer 0 wer 0 gold አይ ጥሩ ሰላም ነሽ:12 hyp አይ ጥሩ ሰላም ነሽ:12 SUCCESS
# [5] cer 0 wer 0 gold ምን እንደሚደረግ:10 hyp ምን እንደሚደረግ:10 SUCCESS
# [6] cer 0 wer 0 gold እንደት ነሽ:7 hyp እንደት ነሽ:7 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 1 wer 1 gold በእውነት ደስ ይላል በጣም:16 hyp በእውነት ደስ ይላም በጣም:16
# [1] cer 0 wer 0 gold አዎ ከበረቱ አይቀሩም:13 hyp አዎ ከበረቱ አይቀሩም:13 SUCCESS
# [2] cer 2 wer 2 gold መቼም አይሞላ:8 hyp ዛቼም አይሞ:7
# [3] cer 1 wer 1 gold አንተ ደህና ነህ:10 hyp አንተ ደህና ተህ:10
# [4] cer 0 wer 0 gold ምን አልሽኝ:7 hyp ምን አልሽኝ:7 SUCCESS
# [5] cer 0 wer 0 gold ሌላ:2 hyp ሌላ:2 SUCCESS
# [6] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [7] cer 0 wer 0 gold እ:1 hyp እ:1 SUCCESS
# [0] cer 0 wer 0 gold ትገዛልሀለች እሷ:10 hyp ትገዛልሀለች እሷ:10 SUCCESS
# [1] cer 0 wer 0 gold አዎ:2 hyp አዎ:2 SUCCESS

# %%
len(R)
# Out:
# 4706

# %%
R[0]
# Out:
# (3, 2, 'ዛሬ እንመለሳለን እንመለሳለን', 'ዛሬ ታንመለለለን እንመለንለን', '')

# %%
len([x for x in R if x[-1]])
# Out:
# 3339

# %%
(4706-3339)/4706
# Out:
# 0.29048023799405015

# %%
sum([x[1] for x in R])
# Out:
# 2178

# %%
sum([len(x[2].split(' ')) for x in R])
# Out:
# 10483

# %%
2178/10483
# Out:
# 0.20776495278069254
