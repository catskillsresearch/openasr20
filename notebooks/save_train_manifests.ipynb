# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import matplotlib.pylab as plt
import numpy as np
import pickle, os, sys, random, logging, json, nemo
from tqdm.auto import tqdm
from Cfg import Cfg
from RecordingCorpus import RecordingCorpus
from multiprocessing import Pool

# %%
C = Cfg('NIST', 16000, 'pashto') 
audio_split_dir=f'{C.build_dir}/audio_split'

# %%
if __name__ == '__main__':
    with Pool(16) as pool:
        recordings = RecordingCorpus(C, pool)
# Out:
#   0%|          | 0/131 [00:00<?, ?it/s][NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:17 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#   1%|          | 1/131 [00:00<02:08,  1.01it/s][NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#   8%|▊         | 11/131 [00:01<01:23,  1.44it/s][NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  16%|█▌        | 21/131 [00:01<00:54,  2.04it/s][NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  19%|█▉        | 25/131 [00:01<00:37,  2.80it/s][NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  22%|██▏       | 29/131 [00:01<00:27,  3.77it/s][NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:18 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  24%|██▍       | 32/131 [00:01<00:19,  4.97it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  27%|██▋       | 35/131 [00:01<00:14,  6.51it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  29%|██▉       | 38/131 [00:02<00:11,  7.86it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  31%|███▏      | 41/131 [00:02<00:08, 10.07it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  34%|███▎      | 44/131 [00:02<00:07, 11.74it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  37%|███▋      | 48/131 [00:02<00:05, 14.76it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  39%|███▉      | 51/131 [00:02<00:05, 14.79it/s][NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:19 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  41%|████      | 54/131 [00:02<00:04, 17.41it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
#  44%|████▎     | 57/131 [00:02<00:04, 16.81it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  46%|████▌     | 60/131 [00:03<00:04, 16.64it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  49%|████▉     | 64/131 [00:03<00:03, 19.02it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  51%|█████     | 67/131 [00:03<00:03, 21.10it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  53%|█████▎    | 70/131 [00:03<00:03, 19.08it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  57%|█████▋    | 75/131 [00:03<00:02, 22.13it/s][NeMo W 2020-10-17 01:17:20 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# ...
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  67%|██████▋   | 88/131 [00:04<00:01, 22.32it/s][NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  69%|██████▉   | 91/131 [00:04<00:01, 21.36it/s][NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  72%|███████▏  | 94/131 [00:04<00:01, 20.72it/s][NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  74%|███████▍  | 97/131 [00:04<00:01, 22.46it/s][NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:21 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  77%|███████▋  | 101/131 [00:04<00:01, 25.82it/s][NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  79%|███████▉  | 104/131 [00:05<00:01, 23.67it/s][NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  82%|████████▏ | 107/131 [00:05<00:01, 20.86it/s][NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  84%|████████▍ | 110/131 [00:05<00:00, 22.90it/s][NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
#  86%|████████▋ | 113/131 [00:05<00:00, 18.28it/s][NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:103: FutureWarning: `item` has been deprecated and will be removed in a future version
#       if isinstance(df_new[df_new['time'] == v]['label'].item(),str):
#
# [NeMo W 2020-10-17 01:17:22 nemo_logging:349] /home/catskills/Desktop/openasr20/txt_to_stm.py:104: FutureWarning: `item` has been deprecated and will be removed in a future version
#       tokenized_text = tokenize(df_new[df_new['time'] == v]['label'].item(), no_Q)
#
# 100%|██████████| 131/131 [00:06<00:00, 21.40it/s]

# %%
from SplitCorpus import SplitCorpus
splits=SplitCorpus.transcript_split(C, recordings)

random.shuffle(splits.artifacts)
n_samples=len(splits.artifacts)

n_train = int(0.9*n_samples)
samples=splits.artifacts
train_samples=samples[0:n_train]
test_samples=samples[n_train:]

for (case, S) in [('train', train_samples), ('test', test_samples)]:
    manifest_fn=f'{C.build_dir}/{case}_manifest.json'
    with open(manifest_fn, 'w', encoding='utf-8') as f_manifest:
        for sample in tqdm(S):
            (_,root,(start,end))=sample.key
            audio = sample.source.value
            duration = sample.source.n_seconds
            transcript = sample.target.value
            audio_path=f'{audio_split_dir}/{root}_{start}_{end}.wav'
            metadata = {
                    "audio_filepath": audio_path,
                    "duration": duration,
                    "text": transcript
                }
            json.dump(metadata, f_manifest)
            f_manifest.write('\n')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7805.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=868.0), HTML(value='')))
